# %% [markdown]
# # Competitor Comparison
#
# The purpose of this notebook is to compare the debiased machine learning Thompson sampling algorithm (DML-TS-NNR) to several competitors.
# The data forms a triangular array.
# The results from this simulation are in the main paper.
#
# This notebook contains three separate simulations that compare these methods.
# In the first simulation, the standard Thompson sampling assumptions hold,
# and the users are assumed to be homogeneous in the sense that their advantage functions (causal effects) are the same.
# The second situation is similar, but users are heterogeneous in the sense that they have different advantage functions.
# In the third simulation, the data-generating mechanism is much more complex.
# In addition to being nonlinear, it also includes effects for users and time.
# Consequently, only the DML-TS-NNR method performs well in this setting.

# %% [markdown]
# # Shared Setup

# %%
# Generic imports
import pandas as pd
import numpy as np
import scipy
import scipy.sparse
from scipy.stats import ttest_1samp
import matplotlib.pyplot as plt
import seaborn as sns
from river import linear_model
import copy
from multiprocessing import Pool, cpu_count
import pickle
import tensorflow as tf
import keras
from keras import layers, regularizers
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-fui159zh because the default path (/home/jovyan/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.
# Matplotlib is building the font cache; this may take a moment.
# 2024-01-18 16:43:15.608068: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-18 16:43:19.349212: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
# Imports from this project
from models.models import OracleTS, StandardTS, ActionCenteredTS, DmlTS, IntelligentPooling, UserLaplacian
from models.river_wrapper import RiverBatchEstimator
from models.bagging_mod import BaggingRegressor
from models.utils import find_neighbors
from simulations.data_generator import DataGenerator

# %%
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=plt.cm.tab10.colors)
plt.rcParams['font.family'] = 'sans-serif'

# %%
# Simulation setup: try some different values
N_STAGES = 200
N_OBSERVATIONS = N_STAGES * (N_STAGES + 1) // 2
N = N_STAGES
T = N_STAGES
THETA = np.array([1., 0.5, -4.])
CONTEXT_DIM = 2
EXTRA_CONTEXT_DIM = 2
LINEAR_BASELINE_COEF = np.array([2., -2., 3.])
THETA_TIME_INIT = np.array([-2., -4., 6.])
P = THETA.size
n_jobs = 25
REPS = 50
N_NEIGHBORS = 5

# %%
def get_max_norm(x):
    squared_norms = (x**2).sum(axis=1)
    norms = np.sqrt(squared_norms)
    max_norm = np.max(norms)
    return max_norm

def get_max_norm_for_pairs(x, pairs):
    x_diffs = x[pairs[0]] - x[pairs[1]]
    max_norm = get_max_norm(x_diffs)
    return max_norm

# %%
homogeneous_data_generator = DataGenerator(stage_max=N_STAGES, assumptions="homogeneous", linear_baseline_coef=LINEAR_BASELINE_COEF, random_seed=1)
homogeneous_data_generator = homogeneous_data_generator.sample_theta(theta_base=THETA)

heterogeneous_data_generator = DataGenerator(stage_max=N_STAGES, assumptions="heterogeneous", linear_baseline_coef=LINEAR_BASELINE_COEF, random_seed=1)
heterogeneous_data_generator = heterogeneous_data_generator.sample_theta(theta_base=THETA)

nonlinear_data_generator = DataGenerator(stage_max=N_STAGES, assumptions="nonlinear", random_seed=3, nonlinear_scale=1.)  # Seed chosen for its interesting nonlinear relationships
nonlinear_data_generator = nonlinear_data_generator.sample_theta(theta_base=THETA, theta_time_init=THETA_TIME_INIT)

# Baseline Reward
num_vals = 101
s1_vals = np.round(np.linspace(-1., 1., num=num_vals), 2)
s2_vals = np.round(np.linspace(-1., 1., num=num_vals), 2)
s1_vals_repped, s2_vals_repped = np.meshgrid(s1_vals, s2_vals)
context_values = np.vstack([s1_vals_repped.flatten(), s2_vals_repped.flatten()]).T
baseline_vals = nonlinear_data_generator._nonlinear_baseline_function(context_values, scale=nonlinear_data_generator.nonlinear_scale)
heatmap_min = np.min(baseline_vals)
heatmap_max = np.max(baseline_vals)

baseline_vals_df = pd.DataFrame(
    data=baseline_vals.reshape((num_vals, num_vals)),
    index=s1_vals,
    columns=s2_vals).sort_index(ascending=False)

fig, ax = plt.subplots(figsize=(5, 3.5))
ax = sns.heatmap(baseline_vals_df, xticklabels=10, yticklabels=10, ax=ax)
plt.xlabel("$s_{1}$")
plt.ylabel("$s_{2}$")
# plt.title("Baseline Reward as a Function of State")
fig.tight_layout()
fig.savefig("figures/baseline_reward.png")
plt.show()

# %%
# Time-specifc thetas
fig, ax = plt.subplots(figsize=(5, 3.5))
for i in range(THETA.size):
    label = "$\\theta^{(idx)}_{t}$".replace("idx", str(i))
    ax.plot(nonlinear_data_generator.theta_time[:, i], alpha=1, label=label)
ax.grid(which='major', color='#DDDDDD', linewidth=0.3)
ax.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=0.3)
ax.minorticks_on()
ax.set_xlabel("t", fontsize=13)
ax.set_ylabel("$\\theta_{t}$", fontsize=13)
# plt.title("Values of $\\theta_{time}$ Plotted Over Time")
ax.legend(fontsize=12)
fig.tight_layout()
fig.savefig("figures/theta_time.png")
plt.show()

# %%
# %%time
# Neural network stuff
nn_input_dim = CONTEXT_DIM + EXTRA_CONTEXT_DIM

featurizer_nn_models = []
for i, data_generator in enumerate([homogeneous_data_generator, heterogeneous_data_generator, nonlinear_data_generator]):
    # Create data
    data_generator = data_generator.generate_all_contexts(context_dim=CONTEXT_DIM, extra_context_dim=EXTRA_CONTEXT_DIM)
    X_train, y_train = data_generator.generate_baselines_for_nn()
    
    data_generator = data_generator.reset()
    data_generator = data_generator.generate_all_contexts(context_dim=CONTEXT_DIM, extra_context_dim=EXTRA_CONTEXT_DIM)
    X_validation, y_validation = data_generator.generate_baselines_for_nn()
    
    # Train model
    penalty = 0.001
    nn_output_dim = 10
    model = keras.Sequential(
        [
            keras.Input(shape=(nn_input_dim,), name="input"),
            layers.Dense(10, activation="relu", name="layer1", kernel_regularizer=regularizers.l2(penalty)),
            layers.Dense(20, activation="relu", name="layer2", kernel_regularizer=regularizers.l2(penalty)),
            layers.Dense(20, activation="tanh", name="layer3", kernel_regularizer=regularizers.l2(penalty)),
            layers.Dense(nn_output_dim, activation="tanh", name="layer4", kernel_regularizer=regularizers.l2(penalty)),
            layers.Dense(1, name="output", kernel_regularizer=regularizers.l2(penalty)),
        ]
    )
    opt = keras.optimizers.Adam(learning_rate=0.01)
    model.compile(loss="mse", optimizer=opt)
    history = model.fit(
        X_train,
        y_train,
        batch_size=200,
        validation_data=(X_validation, y_validation),
        epochs=50 if i == 2 else 20,
        verbose=1
    )
    
    plt.plot(history.history['loss'], label="Train")
    plt.plot(history.history['val_loss'], label="Validation")
    plt.legend()
    plt.show()

    preds_validation = model(X_validation)
    plt.scatter(preds_validation, y_validation)
    plt.show()
    
    # Featurizer model
    featurizer_nn_model = keras.Model(
        inputs=model.input,
        outputs=model.get_layer("layer4").output)
    
    featurizer_nn_models.append(copy.deepcopy(featurizer_nn_model))

homogeneous_featurizer_nn_model = featurizer_nn_models[0]
heterogeneous_featurizer_nn_model = featurizer_nn_models[1]
nonlinear_featurizer_nn_model = featurizer_nn_models[2]
# Out:
# 2024-01-18 16:43:38.102681: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/20
# 200/200 [==============================] - 2s 2ms/step - loss: 1.5087 - val_loss: 1.1005
# Epoch 2/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0659 - val_loss: 1.0673
# Epoch 3/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0545 - val_loss: 1.0803
# Epoch 4/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0453 - val_loss: 1.0842
# Epoch 5/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0412 - val_loss: 1.0527
# Epoch 6/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0383 - val_loss: 1.0608
# Epoch 7/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0368 - val_loss: 1.0398
# Epoch 8/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0329 - val_loss: 1.0443
# Epoch 9/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0272 - val_loss: 1.0408
# Epoch 10/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0281 - val_loss: 1.0401
# Epoch 11/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0319 - val_loss: 1.0737
# Epoch 12/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0295 - val_loss: 1.0474
# Epoch 13/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0275 - val_loss: 1.0508
# Epoch 14/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0293 - val_loss: 1.0398
# Epoch 15/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0254 - val_loss: 1.0406
# Epoch 16/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0228 - val_loss: 1.0384
# Epoch 17/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0230 - val_loss: 1.0473
# Epoch 18/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0290 - val_loss: 1.0370
# Epoch 19/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0350 - val_loss: 1.0393
# Epoch 20/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0319 - val_loss: 1.0446
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 16:43:47           64
# config.json                                    2024-01-18 16:43:47         2589
# variables.h5                                   2024-01-18 16:43:47        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 16:43:46           64
# config.json                                    2024-01-18 16:43:46         2589
# variables.h5                                   2024-01-18 16:43:46        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Epoch 1/20
# 200/200 [==============================] - 1s 2ms/step - loss: 1.5905 - val_loss: 1.1527
# Epoch 2/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0860 - val_loss: 1.0826
# Epoch 3/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0736 - val_loss: 1.0749
# Epoch 4/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0690 - val_loss: 1.0656
# Epoch 5/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0575 - val_loss: 1.0679
# Epoch 6/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0544 - val_loss: 1.0688
# Epoch 7/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0492 - val_loss: 1.0638
# Epoch 8/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0496 - val_loss: 1.0625
# Epoch 9/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0505 - val_loss: 1.0543
# Epoch 10/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0494 - val_loss: 1.0718
# Epoch 11/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0523 - val_loss: 1.0427
# Epoch 12/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0482 - val_loss: 1.0463
# Epoch 13/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0438 - val_loss: 1.0454
# Epoch 14/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0473 - val_loss: 1.0528
# Epoch 15/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0419 - val_loss: 1.0423
# Epoch 16/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0462 - val_loss: 1.0822
# Epoch 17/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0388 - val_loss: 1.0547
# Epoch 18/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0397 - val_loss: 1.0587
# Epoch 19/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0484 - val_loss: 1.0446
# Epoch 20/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0391 - val_loss: 1.0469
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 16:43:53           64
# config.json                                    2024-01-18 16:43:53         2591
# variables.h5                                   2024-01-18 16:43:53        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 16:43:52           64
# config.json                                    2024-01-18 16:43:52         2591
# variables.h5                                   2024-01-18 16:43:52        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Epoch 1/50
# 200/200 [==============================] - 1s 2ms/step - loss: 4.4419 - val_loss: 2.9030
# Epoch 2/50
# 200/200 [==============================] - 0s 1ms/step - loss: 2.5689 - val_loss: 2.4272
# Epoch 3/50
# 200/200 [==============================] - 0s 1ms/step - loss: 2.2765 - val_loss: 2.1024
# Epoch 4/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.9801 - val_loss: 1.8551
# Epoch 5/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.7131 - val_loss: 1.7472
# Epoch 6/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.5796 - val_loss: 1.5566
# Epoch 7/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.5467 - val_loss: 1.4930
# Epoch 8/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.4957 - val_loss: 1.4702
# Epoch 9/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.4423 - val_loss: 1.4052
# Epoch 10/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.4180 - val_loss: 1.3832
# Epoch 11/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3993 - val_loss: 1.3833
# Epoch 12/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3767 - val_loss: 1.4130
# Epoch 13/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3695 - val_loss: 1.3669
# Epoch 14/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3608 - val_loss: 1.3791
# Epoch 15/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3599 - val_loss: 1.4414
# Epoch 16/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3613 - val_loss: 1.3535
# Epoch 17/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3367 - val_loss: 1.4134
# Epoch 18/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3323 - val_loss: 1.3537
# Epoch 19/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3262 - val_loss: 1.2944
# Epoch 20/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3361 - val_loss: 1.3813
# Epoch 21/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3225 - val_loss: 1.3775
# Epoch 22/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3207 - val_loss: 1.3186
# Epoch 23/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3164 - val_loss: 1.3598
# Epoch 24/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3273 - val_loss: 1.3055
# Epoch 25/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3080 - val_loss: 1.2973
# Epoch 26/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3097 - val_loss: 1.3477
# Epoch 27/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3177 - val_loss: 1.3144
# Epoch 28/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3069 - val_loss: 1.3536
# Epoch 29/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3091 - val_loss: 1.3023
# Epoch 30/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3098 - val_loss: 1.3063
# Epoch 31/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3095 - val_loss: 1.3223
# Epoch 32/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3047 - val_loss: 1.3557
# Epoch 33/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.2940 - val_loss: 1.3574
# Epoch 34/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3061 - val_loss: 1.4025
# Epoch 35/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.2885 - val_loss: 1.3177
# Epoch 36/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.2904 - val_loss: 1.2831
# Epoch 37/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3020 - val_loss: 1.3870
# Epoch 38/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.2995 - val_loss: 1.3205
# Epoch 39/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3043 - val_loss: 1.2893
# Epoch 40/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.2759 - val_loss: 1.3143
# Epoch 41/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.2979 - val_loss: 1.2895
# Epoch 42/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.2802 - val_loss: 1.2592
# Epoch 43/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.2820 - val_loss: 1.2920
# Epoch 44/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.2817 - val_loss: 1.3092
# Epoch 45/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.2753 - val_loss: 1.3284
# Epoch 46/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.2722 - val_loss: 1.2899
# Epoch 47/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.2813 - val_loss: 1.3071
# Epoch 48/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.2761 - val_loss: 1.3589
# Epoch 49/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.2843 - val_loss: 1.3173
# Epoch 50/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.2926 - val_loss: 1.2744
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 16:44:07           64
# config.json                                    2024-01-18 16:44:07         2591
# variables.h5                                   2024-01-18 16:44:07        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 16:44:06           64
# config.json                                    2024-01-18 16:44:06         2591
# variables.h5                                   2024-01-18 16:44:06        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# CPU times: user 35.8 s, sys: 9.27 s, total: 45.1 s
# Wall time: 29.2 s

# %%
# # Baseline Reward
num_vals = 101
s1_vals = np.round(np.linspace(-1., 1., num=num_vals), 2)
s2_vals = np.round(np.linspace(-1., 1., num=num_vals), 2)
s1_vals_repped, s2_vals_repped = np.meshgrid(s1_vals, s2_vals)
context_values = np.vstack([s1_vals_repped.flatten(), s2_vals_repped.flatten()]).T
baseline_vals = nonlinear_data_generator._nonlinear_baseline_function(context_values, scale=nonlinear_data_generator.nonlinear_scale)

baseline_vals_df = pd.DataFrame(
    data=baseline_vals.reshape((num_vals, num_vals)),
    index=s1_vals,
    columns=s2_vals).sort_index(ascending=False)

fig, ax = plt.subplots(1, 2, figsize=(10, 3.5))
sns.heatmap(baseline_vals_df, vmin=heatmap_min, vmax=heatmap_max, xticklabels=10, yticklabels=10, ax=ax[0])
ax[0].set_xlabel("$s_{1}$")
ax[0].set_ylabel("$s_{2}$")

nn_context_values = np.hstack([context_values, np.zeros_like(context_values)])
nn_baseline_vals = model(nn_context_values).numpy()
nn_baseline_vals_df = pd.DataFrame(
    data=nn_baseline_vals.reshape((num_vals, num_vals)),
    index=s1_vals,
    columns=s2_vals).sort_index(ascending=False)

sns.heatmap(nn_baseline_vals_df, vmin=heatmap_min, vmax=heatmap_max, xticklabels=10, yticklabels=10, ax=ax[1])
ax[1].set_xlabel("$s_{1}$")
ax[1].set_ylabel("$s_{2}$")

fig.tight_layout()
fig.savefig("figures/nn_baseline_reward_comparison.png")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3.5))
ax = sns.heatmap(nn_baseline_vals_df, vmin=heatmap_min, vmax=heatmap_max, xticklabels=10, yticklabels=10, ax=ax)
plt.xlabel("$s_{1}$")
plt.ylabel("$s_{2}$")
# plt.title("Baseline Reward as a Function of State")
fig.tight_layout()
fig.savefig("figures/nn_baseline_reward.png")
plt.show()

# %%
# This determines the plotting order
non_oracle_method_names = [
    "IntelPooling",
    "DML-TS-NNR-BLM",
    "DML-TS-NNR",
    "DML-TS-SU",
    "AC",
    "Standard",
    "Neural-Linear",
    "NNR-Linear"
]

def create_reward_dict(data_generator, nn, seed):
    np.random.seed(seed)
    user_pairs, L_user = find_neighbors(data_generator.theta_user, N_NEIGHBORS)
    time_pairs, L_time = find_neighbors(data_generator.theta_time, N_NEIGHBORS)
    
    # Doubling these values to make them more reasonable
    d_user = get_max_norm(data_generator.theta_user) * 2
    d_time = get_max_norm(data_generator.theta_time) * 2
    b_user = get_max_norm_for_pairs(data_generator.theta_user, user_pairs) * 2
    b_time = get_max_norm_for_pairs(data_generator.theta_time, time_pairs) * 2
    bagged_lm = RiverBatchEstimator(
        BaggingRegressor(
            linear_model.LinearRegression(l2=1e-8, intercept_lr=0.1),
            n_models=10,
            subsample=0.8
        )
    )

    # Set covariances
    cov_epsilon = 1e-18
    user_cov = np.cov(data_generator.theta_user.T)
    if user_cov.sum() < cov_epsilon:
        user_cov += cov_epsilon * np.eye(user_cov.shape[0])
    time_cov = np.cov(data_generator.theta_time.T)
    if time_cov.sum() < cov_epsilon:
        time_cov += cov_epsilon * np.eye(time_cov.shape[0])

    nn_numpy = lambda x: nn(x).numpy()
    non_oracle_methods_dict = {
        "IntelPooling": IntelligentPooling(N, T, P, DataGenerator._featurize, user_cov=user_cov, time_cov=time_cov),
        "DML-TS-NNR": DmlTS(N, T, P, DataGenerator._featurize, L_user, L_time, user_cov=user_cov, time_cov=time_cov, b_user=b_user, b_time=b_time, d_user=d_user, d_time=d_time, n_neighbors=N_NEIGHBORS),
        "DML-TS-NNR-BLM": DmlTS(N, T, P, DataGenerator._featurize, L_user, L_time, user_cov=user_cov, time_cov=time_cov, b_user=b_user, b_time=b_time, d_user=d_user, d_time=d_time, ml_interactions=True, ml_model=bagged_lm, n_neighbors=N_NEIGHBORS),
        "DML-TS-SU": DmlTS(1, T, P, DataGenerator._featurize, L_user, L_time, user_cov=user_cov, time_cov=time_cov, b_user=b_user, b_time=b_time, d_user=d_user, d_time=d_time, n_neighbors=N_NEIGHBORS, pool_users=False),
        "AC": ActionCenteredTS(N, T, P, DataGenerator._featurize),
        "Standard": StandardTS(N, T, P, DataGenerator._featurize),
        "Neural-Linear": StandardTS(N, T, P, DataGenerator._featurize, nn=nn_numpy, nn_dim=nn_output_dim),
        "NNR-Linear": UserLaplacian(N, T, P, DataGenerator._featurize, L_user, user_cov=user_cov),
    }
    methods_dict = copy.copy(non_oracle_methods_dict)
    methods_dict["Oracle"] = OracleTS(N, T, THETA, data_generator.theta_user, data_generator.theta_time, DataGenerator._featurize)
    
    # Dictionary for storing rewards
    rewards_dict = {k:np.zeros((N, T)) for k in methods_dict}

    # Generate context vectors that we'll use for all models
    data_generator = data_generator.generate_all_contexts(context_dim=CONTEXT_DIM, extra_context_dim=EXTRA_CONTEXT_DIM)

    # Iterate through methods
    for method_name, method in methods_dict.items():
        rewards = []
        data_generator = data_generator.reset()
        method.reset()

        while not data_generator.finished:
            # Randomly samples action from current policy
            context, context_extra, user_idx, time_idx = data_generator.get_current_context()
            action = method.sample_action(context, user_idx, time_idx)

            # Plays action and returns reward
            reward = data_generator.play_action(action)
            rewards_dict[method_name][user_idx, time_idx] = reward

            # Update method inferences
            method.update(context, context_extra, user_idx, time_idx, action, reward)
                
    return rewards_dict

# %%
def run_simulation(data_generator, nn, REPS=REPS, n_jobs=cpu_count()):    
    # Perform whole simulation REPS times
    with Pool(min(REPS, n_jobs)) as p:
        rewards_list_of_dicts = p.starmap(create_reward_dict, zip([data_generator]*REPS, [nn]*REPS, range(REPS)))
        
    rewards_dict = {}
    method_names = list(rewards_list_of_dicts[0].keys())
    non_oracle_method_names = list(set(method_names) - set(["Oracle"]))
    for method_name in method_names:
        rewards_dict[method_name] = np.asarray([
            rewards_list_of_dicts[i][method_name]
            for i in range(REPS)])
                
    return rewards_dict

# %%
def get_avg_stage_reward(a):
    means = [a[:, ::-1].diagonal(i, axis1=1, axis2=2).mean(axis=1) for i in range(-a.shape[1]+1,a.shape[2])]
    return np.asarray(means)[:a.shape[1]]


def plot_rewards_dict(rewards_dict, assumptions):
    fig, ax = plt.subplots(1, 2, figsize=(8, 4))
    ax0 = ax[0]
    ax1 = ax[1]
    
    # Method names
    # non_oracle_method_names = set(rewards_dict.keys()) - {"Oracle",}
    # non_oracle_method_names = sorted(list(non_oracle_method_names))

    # Calculate incremental regret
    oracle_incremental_regret = get_avg_stage_reward(rewards_dict["Oracle"])
    incremental_regret_dict = {
        method_name: (oracle_incremental_regret - get_avg_stage_reward(rewards_dict[method_name])).mean(axis=1)  # Mean over reps
        for method_name in non_oracle_method_names}

    # Calculate cumulative regret
    cumulative_regret_dict = {method_name: np.cumsum(incremental_regret_dict[method_name]) for method_name in non_oracle_method_names}

    # Plot incremental regret
    for method_name in non_oracle_method_names:
        ax0.plot(incremental_regret_dict[method_name], label=method_name, )
    ax0.set_title("(a) Incremental Regret Over Time", pad=10)
    ax0.set_ylabel("Incremental Regret")
    ax0.set_xlabel("Stage")
    ax0.legend()

    # Plot cumulative regret
    for method_name in non_oracle_method_names:
        ax1.plot(cumulative_regret_dict[method_name], label=method_name)
    ax1.set_title("(b) Cumulative Regret Over Time", pad=10)
    ax1.set_ylabel("Cumulative Regret")
    ax1.set_xlabel("Stage")
    plt.legend()

    plt.tight_layout()
    plt.subplots_adjust(top=0.85)
    fig.savefig(f"figures/{assumptions}-regret.png")
    fig.suptitle(f"Regret for {assumptions.capitalize()} Data-Generating Process")
    plt.show()

# %% [markdown]
# # Simulation 1: Homogeneous Users, Linear Baseline, No Time Effects

# %%
# %%time
homogeneous_rewards_dict = run_simulation(homogeneous_data_generator, homogeneous_featurizer_nn_model, n_jobs=n_jobs)
# Out:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 16:44:08           64
# config.json                                    2024-01-18 16:44:08         2589
# variables.h5                                   2024-01-18 16:44:08        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 16:44:08           64
# config.json                                    2024-01-18 16:44:08         2589
# variables.h5                                   2024-01-18 16:44:08        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 16:44:08           64
# config.json                                    2024-01-18 16:44:08         2589
# variables.h5                                   2024-01-18 16:44:08        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 16:44:08           64
# config.json                                    2024-01-18 16:44:08         2589
# variables.h5                                   2024-01-18 16:44:08        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 16:44:08           64
# config.json                                    2024-01-18 16:44:08         2589
# variables.h5                                   2024-01-18 16:44:08        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 16:44:08           64
# config.json                                    2024-01-18 16:44:08         2589
# variables.h5                                   2024-01-18 16:44:08        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# ......dense_1metadata.json                                  2024-01-18 16:44:08           64
#
# config.json                                    2024-01-18 16:44:08         2589
# variables.h5                                   2024-01-18 16:44:08        19128
# .........vars
# ............0
# ............1
#
# ......dense_2.........vars
# ............0
# ............1Keras model archive loading:
#
# ......dense_3
# File Name                                             Modified             Size
# .........varsmetadata.json                                  2024-01-18 16:44:08           64
#
# config.json                                    2024-01-18 16:44:08         2589
# ............0Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:variables.h5                                   2024-01-18 16:44:08        19128
#
#
# ............1...layers
#
# ......input_layer......dense
#
# .........vars.........vars
#
# ...vars............0
#
# ............1
# ......dense_1
# .........vars
# ............0Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
#
# ............1File Name                                             Modified             Size
#
# ......dense_2
# metadata.json                                  2024-01-18 16:44:08           64
# .........vars
# config.json                                    2024-01-18 16:44:08         2589
# ............0
# variables.h5                                   2024-01-18 16:44:08        19128
# ............1
# ......dense_3
# .........vars
# ............0
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:............1
#
# ...layers......input_layer
#
# Keras model archive loading:
# ......dense.........vars
#
# .........vars...varsFile Name                                             Modified             Size
#
#
# metadata.json                                  2024-01-18 16:44:08           64
# ............0config.json                                    2024-01-18 16:44:08         2589
#
# variables.h5                                   2024-01-18 16:44:08        19128
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# ......dense_3
# File Name                                             Modified             Size
# .........vars
# metadata.json                                  2024-01-18 16:44:08           64
# ............0
# config.json                                    2024-01-18 16:44:08         2589
# ............1
# variables.h5                                   2024-01-18 16:44:08        19128
# ......input_layer
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:.........vars
#
# ...vars...layers
#
# ......dense
# .........varsKeras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 16:44:08           64
# config.json                                    2024-01-18 16:44:08         2589
# variables.h5                                   2024-01-18 16:44:08        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 16:44:08           64
# config.json                                    2024-01-18 16:44:08         2589
# variables.h5                                   2024-01-18 16:44:08        19128
#
# ............0Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 16:44:08           64
# config.json                                    2024-01-18 16:44:08         2589
# variables.h5                                   2024-01-18 16:44:08        19128
# File Name                                             Modified             Size
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 16:44:08           64
# metadata.json                                  2024-01-18 16:44:08           64
# config.json                                    2024-01-18 16:44:08         2589
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 16:44:08           64
# config.json                                    2024-01-18 16:44:08         2589
# variables.h5                                   2024-01-18 16:44:08        19128
# variables.h5                                   2024-01-18 16:44:08        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:config.json                                    2024-01-18 16:44:08         2589
#
# variables.h5                                   2024-01-18 16:44:08        19128
#
# ...layers
# Keras model archive loading:
# ......dense
# .........vars
# File Name                                             Modified             Size
# ............0metadata.json                                  2024-01-18 16:44:08           64
#
# config.json                                    2024-01-18 16:44:08         2589
# ............1variables.h5                                   2024-01-18 16:44:08        19128
#
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............1............0
#
# ............1......dense_1
#
# .........vars......input_layer
#
# ............0.........vars
#
# ...vars............1
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
#
# ......dense_2
# .........vars
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 16:44:08           64
# ............0config.json                                    2024-01-18 16:44:08         2589
#
# variables.h5                                   2024-01-18 16:44:08        19128
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layerKeras model archive loading:
#
# .........varsFile Name                                             Modified             Size
#
# metadata.json                                  2024-01-18 16:44:08           64
# config.json                                    2024-01-18 16:44:08         2589
# ...vars
# variables.h5                                   2024-01-18 16:44:08        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# ...layersFile Name                                             Modified             Size
# metadata.json                                  2024-01-18 16:44:08           64
# config.json                                    2024-01-18 16:44:08         2589
#
# variables.h5                                   2024-01-18 16:44:08        19128
# ......dense
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:...layersKeras model archive loading:
#
#
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 16:44:08           64
# ......denseconfig.json                                    2024-01-18 16:44:08         2589
# variables.h5                                   2024-01-18 16:44:08        19128
# ...layers
#
# .........vars......dense
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# ......dense
# ............0
# ............1Keras model archive saving:
#
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 16:44:08           64
# config.json                                    2024-01-18 16:44:08         2589
# variables.h5                                   2024-01-18 16:44:08        19128
#
# ......dense_1.........vars
#
# ............0
# .........vars............1
# Keras model archive loading:
# ......dense_1
# .........vars
# .........vars
# File Name                                             Modified             Size
# ............0
# ............1............0
#
# ............1
# .........vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
#
# metadata.json                                  2024-01-18 16:44:08           64
# config.json                                    2024-01-18 16:44:08         2589
# ............0variables.h5                                   2024-01-18 16:44:08        19128
#
# ............0Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:............1
#
# ......dense_2...layers
# Keras model archive loading:
#
#
# ......dense_1File Name                                             Modified             Size
#
# ......dense_1......densemetadata.json                                  2024-01-18 16:44:08           64
#
#
# config.json                                    2024-01-18 16:44:08         2589
# .........vars
# variables.h5                                   2024-01-18 16:44:08        19128
# ............1.........vars
# .........varsmetadata.json                                  2024-01-18 16:44:08           64
#
# ............0
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:config.json                                    2024-01-18 16:44:08         2589
# ......dense_2
# ............0
#
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 16:44:08           64
# config.json                                    2024-01-18 16:44:08         2589
# variables.h5                                   2024-01-18 16:44:08        19128
#
# .........vars
# ............0variables.h5                                   2024-01-18 16:44:08        19128
# ............0...layers.........vars
#
#
# metadata.json                                  2024-01-18 16:44:08           64
# Keras model archive loading:
# ............1
# File Name                                             Modified             Size
# config.json                                    2024-01-18 16:44:08         2589
# ............1
# variables.h5                                   2024-01-18 16:44:08        19128
# ......dense
#
# ............1
# ......dense_3.........vars
#
# ............0
# ............1
#
# ............1......dense_1
#
# ......dense_3.........vars.........vars
# ............0
#
# ............1......dense_2............0
# ......dense_2
#
# ......input_layer
# .........vars
# ............0.........vars
#
# .........vars
# ............1
# ............0
#
# .........vars............0............1
#
# ............0
# ......dense_1
# ...vars
# ......dense_2
#
# .........vars............1
#
#
# ............1.........vars............0
#
# ......dense_3
#
# ............0Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# ......dense_3
# ............1
# File Name                                             Modified             Size
# .........varsmetadata.json                                  2024-01-18 16:44:08           64
#
#
# .........vars............1config.json                                    2024-01-18 16:44:08         2589
#
# ............0variables.h5                                   2024-01-18 16:44:08        19128
#
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:......dense_2
# ............0
# ......dense_3
#
#
# ............1.........vars...layers
# .........vars............1
#
#
# ......input_layer
# ............0............0............1
# ......dense
#
#
#
# ......input_layer.........vars
# .........vars
# ......input_layer............1............1.........vars
# ...vars
#
#
#
# ............0.........vars
# ......dense_3
#
# ...vars......input_layer
# ...vars
#
#
# ............1.........vars.........vars
#
#
# ............0......dense_1...vars
#
#
# ............1.........vars
#
# ............0......input_layer
#
# .........vars............1
#
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0......dense_2
#
# ............1
# Keras model archive loading:
# File Name                                             Modified             Size
# .........varsmetadata.json                                  2024-01-18 16:44:08           64
#
#
# config.json                                    2024-01-18 16:44:08         2589
# ...layers......dense_1variables.h5                                   2024-01-18 16:44:08        19128
#
#
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# ......denseFile Name                                             Modified             Size
# metadata.json                                  2024-01-18 16:44:08           64
# ............0config.json                                    2024-01-18 16:44:08         2589
# variables.h5                                   2024-01-18 16:44:08        19128
#
# .........vars
# .........vars
#
# ............0............0
#
# ............1............1
#
#
# ......dense_1.........vars
# ............0......dense_3............1
# .........vars
#
# ............1......dense_2Keras model archive loading:
#
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
#
# .........vars
# Keras model archive saving:
# File Name                                             Modified             Size
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 16:44:08           64
# config.json                                    2024-01-18 16:44:08         2589
# variables.h5                                   2024-01-18 16:44:08        19128
#
# ............0
# ............0............1
# ......dense_2
# metadata.json                                  2024-01-18 16:44:08           64
# .........vars
# Keras model archive loading:
# ............0File Name                                             Modified             Size
#
# metadata.json                                  2024-01-18 16:44:08           64
# config.json                                    2024-01-18 16:44:08         2589
# variables.h5                                   2024-01-18 16:44:08        19128
# ............1
# ......dense_3............1
# config.json                                    2024-01-18 16:44:08         2589
# .........vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 16:44:08           64
# config.json                                    2024-01-18 16:44:08         2589
#
# variables.h5                                   2024-01-18 16:44:08        19128
#
# ......input_layer
#
# ............0Keras model archive loading:
# ...layersFile Name                                             Modified             Size
# variables.h5                                   2024-01-18 16:44:08        19128
# .........vars
#
#
# ......dense_3............1
# .........vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
#
# metadata.json                                  2024-01-18 16:44:08           64
# ............0config.json                                    2024-01-18 16:44:08         2589
# variables.h5                                   2024-01-18 16:44:09        19128
#
# ...vars
# ......input_layer............1......densemetadata.json                                  2024-01-18 16:44:08           64
#
# config.json                                    2024-01-18 16:44:08         2589
#
# Keras model archive loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# variables.h5                                   2024-01-18 16:44:08        19128
#
# .........varsFile Name                                             Modified             Size
# .........varsmetadata.json                                  2024-01-18 16:44:09           64
# config.json                                    2024-01-18 16:44:09         2589
# variables.h5                                   2024-01-18 16:44:09        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ......input_layerKeras model archive loading:
#
# File Name                                             Modified             Size
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 16:44:08           64
#
# ............0
# ............1Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# ...varsKeras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 16:44:09           64
# config.json                                    2024-01-18 16:44:09         2589
# variables.h5                                   2024-01-18 16:44:09        19128
#
#
# config.json                                    2024-01-18 16:44:08         2589
#
# variables.h5                                   2024-01-18 16:44:08        19128
# .........vars...layersmetadata.json                                  2024-01-18 16:44:08           64
# ......dense_1
# config.json                                    2024-01-18 16:44:08         2589
# ......dense.........varsvariables.h5                                   2024-01-18 16:44:08        19128
#
#
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
#
# metadata.json                                  2024-01-18 16:44:09           64
# .........varsconfig.json                                    2024-01-18 16:44:09         2589
#
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:variables.h5                                   2024-01-18 16:44:09        19128
# ............0...vars
#
# Keras model archive loading:
# ...layersKeras model archive loading:
# File Name                                             Modified             Size
#
#
# File Name                                             Modified             Size
#
# ............1
# ......dense_1metadata.json                                  2024-01-18 16:44:08           64
# config.json                                    2024-01-18 16:44:08         2589
#
# ............0.........varsvariables.h5                                   2024-01-18 16:44:08        19128
#
#
# ............0............1
#
# ......dense
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 16:44:09           64
# config.json                                    2024-01-18 16:44:09         2589
# variables.h5                                   2024-01-18 16:44:09        19128
# ......dense_2
# metadata.json                                  2024-01-18 16:44:08           64
# .........vars
# ............0Keras model archive loading:
# .........varsconfig.json                                    2024-01-18 16:44:08         2589
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 16:44:08           64
# config.json                                    2024-01-18 16:44:08         2589
# variables.h5                                   2024-01-18 16:44:08        19128
# ............1
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
#
# variables.h5                                   2024-01-18 16:44:08        19128
#
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:...layers
# ...layers
# ...layers
# ............0......dense
#
# ......dense......dense_2
# .........vars
# ............0
# ............1
# ......dense_1............1
# .........vars
#
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 16:44:09           64
# config.json                                    2024-01-18 16:44:09         2589
# variables.h5                                   2024-01-18 16:44:09        19128
#
#
# ............0......dense_1
# .........vars............1
#
# .........vars............1............0Keras model archive loading:
#
#
#
# ............1......dense
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
#
# metadata.json                                  2024-01-18 16:44:09           64
# config.json                                    2024-01-18 16:44:09         2589
#
# variables.h5                                   2024-01-18 16:44:09        19128
# ............0File Name                                             Modified             Size
# ......dense_3......dense_1Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# metadata.json                                  2024-01-18 16:44:08           64
# .........varsKeras weights file (<HDF5 file "variables.h5" (mode r)>) loading:.........vars
# ......dense_2
# config.json                                    2024-01-18 16:44:08         2589
# Keras model archive loading:
# ............0
#
#
#
#
#
# .........vars............1
#
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# ............0File Name                                             Modified             Size
#
# metadata.json                                  2024-01-18 16:44:09           64
# ............1config.json                                    2024-01-18 16:44:09         2589
#
# variables.h5                                   2024-01-18 16:44:09        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 16:44:08           64
# .........vars......dense_2Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:...layers
#
#
# config.json                                    2024-01-18 16:44:08         2589
#
# .........vars......dense...layersvariables.h5                                   2024-01-18 16:44:08        19128
#
#
# ............1
# ............0.........vars............0variables.h5                                   2024-01-18 16:44:08        19128
#
#
#
#
# .........vars......dense......dense_3............0............1
#
#
#
# ......input_layer
#
# .........vars............1.........vars
# ...layers......dense_1............0
#
#
# .........vars
# ............0
# .........vars............1............0............1......dense_3
# ............0
#
#
#
#
# ......dense............1............1
#
# ............0
#
# ...vars
# ......dense_1
# .........vars
#
# ......dense_3............1.........vars............1
#
# ......dense_1
# ......dense_2
# ......dense_2
#
#
# .........vars............0
# .........vars
# ............0.........vars.........vars
#
#
# .........vars......input_layer
# ............1
# ............0
# ............0
#
#
# ............1............1
# ............0
#
#
# ............0............0............1
#
# ......dense_3
#
# ......input_layer
#
# ......dense_3......dense_2............1.........vars.........vars............1
#
#
#
# ...vars............0............1......input_layer
#
#
#
# .........vars
# .........vars.........vars.........vars
# ......dense_2............0Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
#
#
# ............1
# ......dense_1
# ......dense_3
#
# ............0
# ...vars.........vars
#
# .........vars............1
#
#
# ............0
#
# ...vars...layers............1
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:......dense_2
#
#
# ............1......input_layer
#
# ......dense............0.........vars
# .........vars
# ...layers
# ............0
#
# ......input_layer.........vars.........vars
#
#
# ......dense............1
# ............1............0
#
#
#
#
#
# ............0
# ......input_layer...vars
# ......dense_3.........vars............1.........vars
# .........vars......dense_1
# ...vars
#
#
# .........vars
# ............0
# .........vars
# ............1
# ......dense_3
# ............1
# .........vars
#
#
# ......input_layer
#
# ............0.........vars
# ...vars............0
#
# ...vars
# ............0
# ............1
# ............1......dense_2
#
#
# ......input_layer............1
#
# ......dense_1.........vars
# ............0
# ............1
# .........vars.........vars
# ......dense_3
#
#
# ...vars.........vars
# ............0
#
# ............1............0
# ......input_layer
# .........vars
# ...vars
# ............1
#
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 18:02:45           64
# config.json                                    2024-01-18 18:02:45         2589
# variables.h5                                   2024-01-18 18:02:45        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 16:44:08           64
# config.json                                    2024-01-18 16:44:08         2589
# variables.h5                                   2024-01-18 16:44:08        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 18:25:52           64
# config.json                                    2024-01-18 18:25:52         2589
# variables.h5                                   2024-01-18 18:25:52        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 18:02:44           64
# config.json                                    2024-01-18 18:02:44         2589
# variables.h5                                   2024-01-18 18:02:44        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 18:27:07           64
# config.json                                    2024-01-18 18:27:07         2589
# variables.h5                                   2024-01-18 18:27:07        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 18:25:52           64
# config.json                                    2024-01-18 18:25:52         2589
# variables.h5                                   2024-01-18 18:25:52        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 18:31:21           64
# config.json                                    2024-01-18 18:31:21         2589
# variables.h5                                   2024-01-18 18:31:21        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 18:27:06           64
# config.json                                    2024-01-18 18:27:06         2589
# variables.h5                                   2024-01-18 18:27:06        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 18:35:48           64
# config.json                                    2024-01-18 18:35:48         2589
# variables.h5                                   2024-01-18 18:35:48        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 18:31:20           64
# config.json                                    2024-01-18 18:31:20         2589
# variables.h5                                   2024-01-18 18:31:20        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 18:36:06           64
# config.json                                    2024-01-18 18:36:06         2589
# variables.h5                                   2024-01-18 18:36:06        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 18:35:48           64
# config.json                                    2024-01-18 18:35:48         2589
# variables.h5                                   2024-01-18 18:35:48        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 18:36:19           64
# config.json                                    2024-01-18 18:36:19         2589
# variables.h5                                   2024-01-18 18:36:19        19128
# metadata.json                                  2024-01-18 18:36:06           64
# config.json                                    2024-01-18 18:36:06         2589
# variables.h5                                   2024-01-18 18:36:06        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 18:36:18           64
# config.json                                    2024-01-18 18:36:18         2589
# variables.h5                                   2024-01-18 18:36:18        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 18:36:21           64
# config.json                                    2024-01-18 18:36:21         2589
# variables.h5                                   2024-01-18 18:36:21        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 18:36:22           64
# config.json                                    2024-01-18 18:36:22         2589
# variables.h5                                   2024-01-18 18:36:22        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 18:36:20           64
# config.json                                    2024-01-18 18:36:20         2589
# variables.h5                                   2024-01-18 18:36:20        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# File Name                                             Modified             Size
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# ...
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 18:36:33           64
# config.json                                    2024-01-18 18:36:33         2589
# variables.h5                                   2024-01-18 18:36:33        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 18:36:28           64
# config.json                                    2024-01-18 18:36:28         2589
# variables.h5                                   2024-01-18 18:36:28        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 18:36:34           64
# config.json                                    2024-01-18 18:36:34         2589
# variables.h5                                   2024-01-18 18:36:34        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 18:36:32           64
# config.json                                    2024-01-18 18:36:32         2589
# variables.h5                                   2024-01-18 18:36:32        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 18:36:37           64
# config.json                                    2024-01-18 18:36:37         2589
# variables.h5                                   2024-01-18 18:36:37        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 18:36:34           64
# config.json                                    2024-01-18 18:36:34         2589
# variables.h5                                   2024-01-18 18:36:34        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 18:36:43           64
# config.json                                    2024-01-18 18:36:43         2589
# variables.h5                                   2024-01-18 18:36:43        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 18:36:36           64
# config.json                                    2024-01-18 18:36:36         2589
# variables.h5                                   2024-01-18 18:36:36        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 18:45:28           64
# config.json                                    2024-01-18 18:45:28         2589
# variables.h5                                   2024-01-18 18:45:28        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 18:36:42           64
# config.json                                    2024-01-18 18:36:42         2589
# variables.h5                                   2024-01-18 18:36:42        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 18:50:39           64
# config.json                                    2024-01-18 18:50:39         2589
# variables.h5                                   2024-01-18 18:50:39        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 18:45:28           64
# config.json                                    2024-01-18 18:45:28         2589
# variables.h5                                   2024-01-18 18:45:28        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# File Name                                             Modified             Size
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 18:51:34           64
# config.json                                    2024-01-18 18:51:34         2589
# variables.h5                                   2024-01-18 18:51:34        19128
# metadata.json                                  2024-01-18 18:50:38           64
# config.json                                    2024-01-18 18:50:38         2589
# variables.h5                                   2024-01-18 18:50:38        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# Keras model archive loading:
# metadata.json                                  2024-01-18 18:51:41           64
# config.json                                    2024-01-18 18:51:41         2589
# variables.h5                                   2024-01-18 18:51:41        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 18:51:34           64
# config.json                                    2024-01-18 18:51:34         2589
# variables.h5                                   2024-01-18 18:51:34        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 18:52:00           64
# config.json                                    2024-01-18 18:52:00         2589
# variables.h5                                   2024-01-18 18:52:00        19128
# metadata.json                                  2024-01-18 18:51:40           64
# config.json                                    2024-01-18 18:51:40         2589
# variables.h5                                   2024-01-18 18:51:40        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 19:03:39           64
# config.json                                    2024-01-18 19:03:39         2589
# File Name                                             Modified             Size
# variables.h5                                   2024-01-18 19:03:39        19128
# metadata.json                                  2024-01-18 18:52:00           64
# config.json                                    2024-01-18 18:52:00         2589
# variables.h5                                   2024-01-18 18:52:00        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# File Name                                             Modified             Size
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 19:04:36           64
# config.json                                    2024-01-18 19:04:36         2589
# variables.h5                                   2024-01-18 19:04:36        19128
# metadata.json                                  2024-01-18 19:03:38           64
# config.json                                    2024-01-18 19:03:38         2589
# variables.h5                                   2024-01-18 19:03:38        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 19:04:36           64
# config.json                                    2024-01-18 19:04:36         2589
# variables.h5                                   2024-01-18 19:04:36        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# CPU times: user 1.57 s, sys: 1.12 s, total: 2.69 s
# Wall time: 2h 47min 3s

# %%
homogeneous_rewards_filename = "checkpoints/homogeneous_rewards.pkl"
with open(homogeneous_rewards_filename, 'wb') as file:
    pickle.dump(homogeneous_rewards_dict, file, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open(homogeneous_rewards_filename, "rb") as file:
    homogeneous_rewards_dict = pickle.load(file)

# %%
plot_rewards_dict(homogeneous_rewards_dict, "homogeneous")

# %% [markdown]
# # Simulation 2: Heterogeneous Users, Linear Baseline, No Time Effects

# %%
# %%time
heterogeneous_rewards_dict = run_simulation(heterogeneous_data_generator, heterogeneous_featurizer_nn_model, n_jobs=n_jobs)
# Out:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 19:31:14           64
# config.json                                    2024-01-18 19:31:14         2591
# variables.h5                                   2024-01-18 19:31:14        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 19:31:14           64
# config.json                                    2024-01-18 19:31:14         2591
# variables.h5                                   2024-01-18 19:31:14        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 19:31:14           64
# config.json                                    2024-01-18 19:31:14         2591
# variables.h5                                   2024-01-18 19:31:14        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 19:31:14           64
# config.json                                    2024-01-18 19:31:14         2591
# variables.h5                                   2024-01-18 19:31:14        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 19:31:14           64
# config.json                                    2024-01-18 19:31:14         2591
# variables.h5                                   2024-01-18 19:31:14        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 19:31:14           64
# config.json                                    2024-01-18 19:31:14         2591
# variables.h5                                   2024-01-18 19:31:14        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 19:31:14           64
# config.json                                    2024-01-18 19:31:14         2591
# variables.h5                                   2024-01-18 19:31:14        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 19:31:14           64
# config.json                                    2024-01-18 19:31:14         2591
# variables.h5                                   2024-01-18 19:31:14        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 19:31:14           64
# config.json                                    2024-01-18 19:31:14         2591
# variables.h5                                   2024-01-18 19:31:14        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
#
# ...layers...layers
#
# ......dense......dense
#
# .........vars.........vars
#
# Keras model archive loading:
# ............0............0
#
# File Name                                             Modified             Size
# ............1............1metadata.json                                  2024-01-18 19:31:14           64
#
#
# config.json                                    2024-01-18 19:31:14         2591
# variables.h5                                   2024-01-18 19:31:14        19128
# ......dense_1......dense_1
#
# .........vars.........varsKeras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
#
#
# ............0............0
#
# ...layers
# ............1............1
# ......denseKeras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
#
#
# ......dense_2......dense_2.........varsFile Name                                             Modified             Size
#
#
#
# .........vars.........vars............0metadata.json                                  2024-01-18 19:31:14           64
#
#
#
# ............0............0
# ............1config.json                                    2024-01-18 19:31:14         2591
#
#
# ............1............1
# ......dense_1
# variables.h5                                   2024-01-18 19:31:14        19128
#
# ......dense_3......dense_3.........vars
#
#
# .........vars.........vars............0
#
#
# ............0............0............1
#
#
# ............1............1......dense_2
#
#
# ......input_layer.........vars......input_layer
#
#
# ............0.........vars.........vars
#
#
# ...vars...vars............1
#
#
# ......dense_3
# .........vars
# ............0
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:............1
#
# Keras model archive loading:
# ...layers
# ......input_layer
# ......dense
# .........vars
# File Name                                             Modified             Size
# .........vars...vars
# metadata.json                                  2024-01-18 19:31:14           64
#
# ............0config.json                                    2024-01-18 19:31:14         2591
#
# variables.h5                                   2024-01-18 19:31:14        19128
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:File Name                                             Modified             Size
# metadata.json                                  2024-01-18 19:31:14           64
# config.json                                    2024-01-18 19:31:14         2591
# variables.h5                                   2024-01-18 19:31:14        19128
#
# ...layers...vars
# Keras model archive loading:
#
# File Name                                             Modified             Size
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 19:31:14           64
# config.json                                    2024-01-18 19:31:14         2591
# variables.h5                                   2024-01-18 19:31:14        19128
# ......densemetadata.json                                  2024-01-18 19:31:14           64
#
# Keras model archive loading:
# .........varsFile Name                                             Modified             Size
# metadata.json                                  2024-01-18 19:31:14           64
# config.json                                    2024-01-18 19:31:14         2591
# config.json                                    2024-01-18 19:31:14         2591
# variables.h5                                   2024-01-18 19:31:14        19128
#
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 19:31:14           64
# config.json                                    2024-01-18 19:31:14         2591
# variables.h5                                   2024-01-18 19:31:14        19128
# ............0variables.h5                                   2024-01-18 19:31:14        19128
#
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 19:31:14           64
# config.json                                    2024-01-18 19:31:14         2591
# variables.h5                                   2024-01-18 19:31:14        19128
# ............1Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
#
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 19:31:14           64
# config.json                                    2024-01-18 19:31:14         2591
# ......dense_1variables.h5                                   2024-01-18 19:31:14        19128
#
# .........vars
# ............0
#
# ............1File Name                                             Modified             Size
# ............1......dense_2
# .........varsKeras model archive loading:
#
# ............0
# metadata.json                                  2024-01-18 19:31:14           64
#
# ......dense_3
# .........vars
# ............0config.json                                    2024-01-18 19:31:14         2591
# variables.h5                                   2024-01-18 19:31:14        19128
#
# ............1
# ......input_layer
# .........varsKeras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
#
# File Name                                             Modified             Size
# ...layersmetadata.json                                  2024-01-18 19:31:14           64
#
# ...vars
# config.json                                    2024-01-18 19:31:14         2591
# variables.h5                                   2024-01-18 19:31:14        19128
# ......denseKeras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
#
# .........vars
# ...layers............0
# ............1
# ......dense_1
# ......dense.........vars
#
# Keras model archive loading:
# ............0
#
# .........varsFile Name                                             Modified             Size
#
# metadata.json                                  2024-01-18 19:31:14           64
# ............0
# config.json                                    2024-01-18 19:31:14         2591
# variables.h5                                   2024-01-18 19:31:14        19128
# ............1Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
#
# ......dense_1...layers
# ............1
# ......dense
# .........vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# .........vars......dense_2............0
#
#
# .........vars
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
#
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:............0
# ......dense_2
#
# ...layers............1
# .........vars
#
# ............0............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 19:31:14           64
# config.json                                    2024-01-18 19:31:14         2591
# variables.h5                                   2024-01-18 19:31:14        19128
# ......dense......dense_3
#
# ............0
# .........vars.........vars............1
#
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# Keras model archive loading:
#
# ............0
# ......dense_1............0
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# ............1File Name                                             Modified             Size
# ............1
# .........varsFile Name                                             Modified             Size
# metadata.json                                  2024-01-18 19:31:14           64
# config.json                                    2024-01-18 19:31:14         2591
# variables.h5                                   2024-01-18 19:31:14        19128
# metadata.json                                  2024-01-18 19:31:14           64
# config.json                                    2024-01-18 19:31:14         2591
# ............1Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# Keras model archive loading:
# ............0
#
#
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# variables.h5                                   2024-01-18 19:31:14        19128
#
# File Name                                             Modified             Size
# ............1metadata.json                                  2024-01-18 19:31:14           64
# config.json                                    2024-01-18 19:31:14         2591
# variables.h5                                   2024-01-18 19:31:14        19128
#
# File Name                                             Modified             Size
#
# ......dense_1
#
# ......dense_2.........varsKeras model archive loading:
#
#
# .........vars
# ............0......input_layer
# ......dense_3
#
# ............0.........vars............1File Name                                             Modified             Size
#
# .........vars...layers
# metadata.json                                  2024-01-18 19:31:14           64
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
#
# ............0
# config.json                                    2024-01-18 19:31:14         2591
#
# variables.h5                                   2024-01-18 19:31:14        19128
# ...layers
# ......dense
#
# ...vars.........vars
# metadata.json                                  2024-01-18 19:31:14           64
# File Name                                             Modified             Size
# config.json                                    2024-01-18 19:31:14         2591
# metadata.json                                  2024-01-18 19:31:14           64
# config.json                                    2024-01-18 19:31:14         2591
# variables.h5                                   2024-01-18 19:31:14        19128
# variables.h5                                   2024-01-18 19:31:14        19128
# ......dense_2
# Keras model archive loading:
# .........vars............1............1
# File Name                                             Modified             Size
#
# metadata.json                                  2024-01-18 19:31:14           64
# config.json                                    2024-01-18 19:31:14         2591
# variables.h5                                   2024-01-18 19:31:14        19128
# ............0......input_layer
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 19:31:14           64
# config.json                                    2024-01-18 19:31:14         2591
# variables.h5                                   2024-01-18 19:31:14        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:.........vars
# Keras model archive loading:
#
#
# ...layers...varsFile Name                                             Modified             Size
# ............1metadata.json                                  2024-01-18 19:31:14           64
#
#
# config.json                                    2024-01-18 19:31:14         2591
# variables.h5                                   2024-01-18 19:31:14        19128
#
# ......dense_3
# ......dense
# .........vars.........vars
#
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:............0
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
#
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# ............0File Name                                             Modified             Size
#
# ............1metadata.json                                  2024-01-18 19:31:14           64
# config.json                                    2024-01-18 19:31:14         2591
# variables.h5                                   2024-01-18 19:31:14        19128
#
# ............1......dense
#
# Keras model archive loading:
# ......input_layerFile Name                                             Modified             Size
#
#
# metadata.json                                  2024-01-18 19:31:14           64
# .........varsconfig.json                                    2024-01-18 19:31:14         2591
#
# ............0
# variables.h5                                   2024-01-18 19:31:14        19128
# .........vars......dense_1............1
#
# ......dense_1.........vars
#
#
# ............0.........vars
# ............1
# ............0......dense_3
# ...vars
#
# .........vars
#
#
# ............0............0
#
# ......dense_2............1.........vars
# ......input_layer
# .........vars
# ...vars
#
# ............0
# ............1............1
# ......dense_2
#
# ............1Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 19:31:14           64
# .........varsconfig.json                                    2024-01-18 19:31:14         2591
# variables.h5                                   2024-01-18 19:31:14        19128
#
#
#
# ......dense_3............0
#
# .........vars............1......dense_1
#
# ............0
# ......dense_3Keras model archive loading:
#
#
# .........vars
# File Name                                             Modified             Size
# .........vars............1metadata.json                                  2024-01-18 19:31:14           64
#
#
# ............0......input_layer............0
# ............1
#
# config.json                                    2024-01-18 19:31:14         2591
#
# .........vars............1
#
# ......dense_2...varsvariables.h5                                   2024-01-18 19:31:14        19128
#
#
# .........vars......input_layerKeras weights file (<HDF5 file "variables.h5" (mode r)>) loading:Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
#
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 19:31:14           64
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:config.json                                    2024-01-18 19:31:14         2591
# variables.h5                                   2024-01-18 19:31:14        19128
# ............0
#
# .........vars
#
# ...layers...vars............1
#
# ......dense_3
#
#
# .........vars.........vars......dense...layers
#
#
# ............0
# ......dense............1
#
#
# ......input_layer
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# ............0File Name                                             Modified             Size
#
# metadata.json                                  2024-01-18 19:31:14           64
# Keras model archive loading:
# ............1.........varsconfig.json                                    2024-01-18 19:31:14         2591
#
# variables.h5                                   2024-01-18 19:31:14        19128
#
# File Name                                             Modified             Size
# ......dense_1............0
# .........vars.........vars
#
#
# ...vars............0
# ............1
#
# ......dense_2............0
# ............1
# .........vars
# ......dense_1
#
# ............1
# .........vars
# ......dense_3
# .........vars
# ............0
# ............1......input_layer
# ............0
#
# ............1.........vars
# ......dense_2
#
# .........vars
# ............0
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# ............1metadata.json                                  2024-01-18 19:31:14           64
# config.json                                    2024-01-18 19:31:14         2591
#
# variables.h5                                   2024-01-18 19:31:14        19128
# ......dense_3
# .........vars
# ...vars
# metadata.json                                  2024-01-18 19:31:14           64
# Keras model archive loading:
# File Name                                             Modified             Size
# ............0
# ............1metadata.json                                  2024-01-18 19:31:14           64
#
# ......input_layer
# .........varsconfig.json                                    2024-01-18 19:31:14         2591
#
# ...vars
# config.json                                    2024-01-18 19:31:14         2591
# variables.h5                                   2024-01-18 19:31:14        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layersKeras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
#
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 19:31:14           64
# config.json                                    2024-01-18 19:31:14         2591
# variables.h5                                   2024-01-18 19:31:15        19128
# Keras model archive loading:
# ......denseFile Name                                             Modified             Size
#
# Keras model archive loading:
# metadata.json                                  2024-01-18 19:31:14           64
# config.json                                    2024-01-18 19:31:14         2591
# .........varsvariables.h5                                   2024-01-18 19:31:14        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 19:31:15           64
# config.json                                    2024-01-18 19:31:15         2591
# variables.h5                                   2024-01-18 19:31:15        19128
#
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:File Name                                             Modified             Size
# Keras model archive loading:
# ............0File Name                                             Modified             Size
# variables.h5                                   2024-01-18 19:31:14        19128
# metadata.json                                  2024-01-18 19:31:14           64
# config.json                                    2024-01-18 19:31:14         2591
#
# variables.h5                                   2024-01-18 19:31:14        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
#
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 19:31:15           64
# ............1config.json                                    2024-01-18 19:31:15         2591
# variables.h5                                   2024-01-18 19:31:15        19128
#
# metadata.json                                  2024-01-18 19:31:14           64
# Keras model archive loading:
# ...layersFile Name                                             Modified             Size
# metadata.json                                  2024-01-18 19:31:14           64
# config.json                                    2024-01-18 19:31:14         2591
# variables.h5                                   2024-01-18 19:31:14        19128
# ......dense_1
# .........vars
# ............0
# config.json                                    2024-01-18 19:31:14         2591
# ............1
#
# ......dense_2
# .........varsKeras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ............0
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 19:31:15           64
# config.json                                    2024-01-18 19:31:15         2591
# variables.h5                                   2024-01-18 19:31:14        19128
# variables.h5                                   2024-01-18 19:31:15        19128
# ......dense............1Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ......dense_3
#
# .........vars.........vars
# ............0
# ............1
#
# ......dense_1
# .........vars
# ............0
#
#
# ............1
# ............0......dense_2Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# .........vars
# ...layers............0
#
#
# ............1Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:Keras model archive loading:
#
#
#
# ...layers............1Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:...layers
#
# ......input_layer...layers
# File Name                                             Modified             Size
# ...layers
# ......dense
#
# .........vars.........vars......dense
# metadata.json                                  2024-01-18 19:31:14           64
#
# ......denseconfig.json                                    2024-01-18 19:31:14         2591
#
# ......dense_3Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# .........vars.........vars......dense
# variables.h5                                   2024-01-18 19:31:14        19128
#
#
# ...layersKeras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# ............0File Name                                             Modified             Size
#
#
# .........vars
# metadata.json                                  2024-01-18 19:31:15           64
# ............0............0
#
# config.json                                    2024-01-18 19:31:15         2591
# ............1variables.h5                                   2024-01-18 19:31:15        19128
#
# ......dense
#
#
# ...vars......dense_1.........vars
#
# ............1.........vars............1
# .........vars
# ......dense............0............0
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
#
#
#
#
# ...layers............1............1............0
#
#
#
#
#
# ......dense_1......dense_1.........vars......input_layer......dense
#
# .........vars.........vars
#
# ............0
# .........vars
#
# ............1............1......dense_1
#
# ............0............0......dense_2Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
#
#
# .........vars
#
#
# ............0
#
#
# ............1.........vars
# ............0
# ............1......dense_2............1.........vars
# ......dense_2
# .........vars
# ............0
#
# ............1
#
# ......dense_3
# .........vars
#
# .........vars
# ...vars......dense_2
# ............0
# ...layers
# .........vars............1......dense_3
#
# ............0......dense_1
# ............0
# ............0
#
# ............1............1
# ......dense
#
# ............0.........vars
#
# .........vars......dense_3
#
#
# ............0
#
#
# ............1............1............1
# .........vars
# ............0
# ......dense_1......input_layer......dense_2
#
#
#
# .........varsKeras weights file (<HDF5 file "variables.h5" (mode r)>) loading:.........vars............1
#
# .........vars............0
# ......input_layer
#
#
# ............0............0.........vars............1
#
#
# ...vars
#
#
# ............1............1......dense_2
#
# ...layers.........vars
# ......dense_3
#
# ......dense............0
# .........vars
#
# .........vars............0
# ............0............0
#
#
# ............1............1
# ............1......dense_3
# ......input_layer
# ......dense_1.........vars
#
# ...vars
#
#
#
# ............1............1
#
# ......input_layer
# .........vars.........vars
# ...vars
#
# ......dense_1.........vars
#
# .........vars............0
#
# .........vars...vars
#
#
# ......dense_1
# .........vars......dense_3
# ............0............1............0
#
#
#
#
# ............1
# ......input_layer............1............0......dense_2
#
#
# .........vars.........vars......dense_2
#
#
# ............0.........vars.........vars
# ............0............0
# ............1
#
# ......input_layer
# ............1...vars
#
#
# ......dense_3............1
#
# .........vars......dense_3
#
# ............0.........vars
#
# ............1............0
#
# ......input_layer............1
#
# ......input_layer.........vars
#
# .........vars...vars
#
#
# ...vars
# .........vars
# ...vars
#
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 20:55:54           64
# config.json                                    2024-01-18 20:55:54         2591
# variables.h5                                   2024-01-18 20:55:54        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 19:31:14           64
# config.json                                    2024-01-18 19:31:14         2591
# variables.h5                                   2024-01-18 19:31:14        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 20:56:06           64
# config.json                                    2024-01-18 20:56:06         2591
# variables.h5                                   2024-01-18 20:56:06        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 20:55:54           64
# config.json                                    2024-01-18 20:55:54         2591
# variables.h5                                   2024-01-18 20:55:54        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 20:56:06           64
# config.json                                    2024-01-18 20:56:06         2591
# variables.h5                                   2024-01-18 20:56:06        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 20:58:54           64
# config.json                                    2024-01-18 20:58:54         2591
# variables.h5                                   2024-01-18 20:58:54        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:02:56           64
# config.json                                    2024-01-18 21:02:56         2591
# variables.h5                                   2024-01-18 21:02:56        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 20:58:54           64
# config.json                                    2024-01-18 20:58:54         2591
# variables.h5                                   2024-01-18 20:58:54        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:02:56           64
# config.json                                    2024-01-18 21:02:56         2591
# variables.h5                                   2024-01-18 21:02:56        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:05:16           64
# config.json                                    2024-01-18 21:05:16         2591
# variables.h5                                   2024-01-18 21:05:16        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:10:30           64
# config.json                                    2024-01-18 21:10:30         2591
# variables.h5                                   2024-01-18 21:10:30        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:05:16           64
# config.json                                    2024-01-18 21:05:16         2591
# variables.h5                                   2024-01-18 21:05:16        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:10:34           64
# config.json                                    2024-01-18 21:10:34         2591
# variables.h5                                   2024-01-18 21:10:34        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:10:30           64
# config.json                                    2024-01-18 21:10:30         2591
# variables.h5                                   2024-01-18 21:10:30        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:10:34           64
# config.json                                    2024-01-18 21:10:34         2591
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:11:17           64
# config.json                                    2024-01-18 21:11:17         2591
# variables.h5                                   2024-01-18 21:11:17        19128
# variables.h5                                   2024-01-18 21:10:34        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:11:25           64
# config.json                                    2024-01-18 21:11:25         2591
# variables.h5                                   2024-01-18 21:11:25        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:11:16           64
# config.json                                    2024-01-18 21:11:16         2591
# variables.h5                                   2024-01-18 21:11:16        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:11:27           64
# ...
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:12:01           64
# config.json                                    2024-01-18 21:12:01         2591
# variables.h5                                   2024-01-18 21:12:01        19128
# metadata.json                                  2024-01-18 21:11:50           64
# config.json                                    2024-01-18 21:11:50         2591
# variables.h5                                   2024-01-18 21:11:50        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:12:20           64
# config.json                                    2024-01-18 21:12:20         2591
# variables.h5                                   2024-01-18 21:12:20        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:12:00           64
# config.json                                    2024-01-18 21:12:00         2591
# variables.h5                                   2024-01-18 21:12:00        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:12:44           64
# config.json                                    2024-01-18 21:12:44         2591
# variables.h5                                   2024-01-18 21:12:44        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:12:20           64
# config.json                                    2024-01-18 21:12:20         2591
# variables.h5                                   2024-01-18 21:12:20        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:13:17           64
# config.json                                    2024-01-18 21:13:17         2591
# variables.h5                                   2024-01-18 21:13:17        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:12:44           64
# config.json                                    2024-01-18 21:12:44         2591
# variables.h5                                   2024-01-18 21:12:44        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:13:46           64
# config.json                                    2024-01-18 21:13:46         2591
# variables.h5                                   2024-01-18 21:13:46        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:13:16           64
# config.json                                    2024-01-18 21:13:16         2591
# variables.h5                                   2024-01-18 21:13:16        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:14:34           64
# config.json                                    2024-01-18 21:14:34         2591
# variables.h5                                   2024-01-18 21:14:34        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:13:46           64
# config.json                                    2024-01-18 21:13:46         2591
# variables.h5                                   2024-01-18 21:13:46        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:14:49           64
# config.json                                    2024-01-18 21:14:49         2591
# variables.h5                                   2024-01-18 21:14:49        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:14:34           64
# config.json                                    2024-01-18 21:14:34         2591
# variables.h5                                   2024-01-18 21:14:34        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:17:20           64
# config.json                                    2024-01-18 21:17:20         2591
# variables.h5                                   2024-01-18 21:17:20        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:14:48           64
# config.json                                    2024-01-18 21:14:48         2591
# variables.h5                                   2024-01-18 21:14:48        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:18:42           64
# config.json                                    2024-01-18 21:18:42         2591
# variables.h5                                   2024-01-18 21:18:42        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:17:20           64
# config.json                                    2024-01-18 21:17:20         2591
# variables.h5                                   2024-01-18 21:17:20        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:19:04           64
# config.json                                    2024-01-18 21:19:04         2591
# variables.h5                                   2024-01-18 21:19:04        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:18:42           64
# config.json                                    2024-01-18 21:18:42         2591
# variables.h5                                   2024-01-18 21:18:42        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:19:04           64
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:19:06           64
# config.json                                    2024-01-18 21:19:06         2591
# variables.h5                                   2024-01-18 21:19:06        19128
# config.json                                    2024-01-18 21:19:04         2591
# variables.h5                                   2024-01-18 21:19:04        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:19:06           64
# config.json                                    2024-01-18 21:19:06         2591
# variables.h5                                   2024-01-18 21:19:06        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# CPU times: user 1.62 s, sys: 1.25 s, total: 2.87 s
# Wall time: 2h 4min 13s

# %%
heterogeneous_rewards_filename = "checkpoints/heterogeneous_rewards.pkl"
with open(heterogeneous_rewards_filename, 'wb') as file:
    pickle.dump(heterogeneous_rewards_dict, file, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open(heterogeneous_rewards_filename, "rb") as file:
    heterogeneous_rewards_dict = pickle.load(file)

# %%
plot_rewards_dict(heterogeneous_rewards_dict, "heterogeneous")

# %% [markdown]
# # Simulation 3: Nonlinear Baseline and User-/Time-specific Effects

# %%
# %%time
nonlinear_rewards_dict = run_simulation(nonlinear_data_generator, nonlinear_featurizer_nn_model, n_jobs=n_jobs)
# Out:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:35:29           64
# config.json                                    2024-01-18 21:35:29         2591
# variables.h5                                   2024-01-18 21:35:29        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:35:28           64
# config.json                                    2024-01-18 21:35:28         2591
# variables.h5                                   2024-01-18 21:35:28        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:35:29           64
# config.json                                    2024-01-18 21:35:29         2591
# variables.h5                                   2024-01-18 21:35:29        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:35:28           64
# config.json                                    2024-01-18 21:35:28         2591
# variables.h5                                   2024-01-18 21:35:28        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:35:29           64
# config.json                                    2024-01-18 21:35:29         2591
# variables.h5                                   2024-01-18 21:35:29        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:35:28           64
# config.json                                    2024-01-18 21:35:28         2591
# variables.h5                                   2024-01-18 21:35:28        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# ......dense_1metadata.json                                  2024-01-18 21:35:29           64
#
# config.json                                    2024-01-18 21:35:29         2591
# .........varsvariables.h5                                   2024-01-18 21:35:29        19128
#
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0Keras model archive loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
#
# ............1...layers
#
# File Name                                             Modified             Size
# ......input_layer......dense
# metadata.json                                  2024-01-18 21:35:28           64
#
# .........varsconfig.json                                    2024-01-18 21:35:28         2591
#
# .........varsvariables.h5                                   2024-01-18 21:35:28        19128
#
# ...vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# ............1File Name                                             Modified             Size
#
# metadata.json                                  2024-01-18 21:35:29           64
# config.json                                    2024-01-18 21:35:29         2591
# variables.h5                                   2024-01-18 21:35:30        19128
# ......input_layerKeras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
#
# .........vars
# ...layers
# ...vars
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# Keras model archive loading:
# ......dense_2
# .........varsFile Name                                             Modified             Size
#
# metadata.json                                  2024-01-18 21:35:28           64
# ............0config.json                                    2024-01-18 21:35:28         2591
#
# variables.h5                                   2024-01-18 21:35:30        19128
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:35:30           64
# config.json                                    2024-01-18 21:35:30         2591
# variables.h5                                   2024-01-18 21:35:30        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:35:30           64
# config.json                                    2024-01-18 21:35:30         2591
# variables.h5                                   2024-01-18 21:35:30        19128
# Keras model archive loading:
# Keras model archive loading:
# File Name                                             Modified             Size
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:35:30           64
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:35:30           64
# config.json                                    2024-01-18 21:35:30         2591
# variables.h5                                   2024-01-18 21:35:30        19128
# config.json                                    2024-01-18 21:35:30         2591
# metadata.json                                  2024-01-18 21:35:30           64
#
# variables.h5                                   2024-01-18 21:35:30        19128
# config.json                                    2024-01-18 21:35:30         2591
# Keras model archive loading:
# variables.h5                                   2024-01-18 21:35:30        19128
# File Name                                             Modified             Size
# ...layersmetadata.json                                  2024-01-18 21:35:30           64
# config.json                                    2024-01-18 21:35:30         2591
#
# variables.h5                                   2024-01-18 21:35:30        19128
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
#
# ............1
# ......dense_2
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# .........varsFile Name                                             Modified             Size
#
# metadata.json                                  2024-01-18 21:35:30           64
# config.json                                    2024-01-18 21:35:30         2591
# ............0variables.h5                                   2024-01-18 21:35:30        19128
#
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# Keras model archive loading:
# ......input_layer
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:.........varsFile Name                                             Modified             Size
#
#
# metadata.json                                  2024-01-18 21:35:30           64
# ...varsconfig.json                                    2024-01-18 21:35:30         2591
# ...layers
# variables.h5                                   2024-01-18 21:35:30        19128
#
# ......dense
# .........vars
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:............0
#
# ...layersKeras weights file (<HDF5 file "variables.h5" (mode r)>) loading:............1
#
#
# ......dense...layers
# ......dense_1
#
# .........vars
# ......dense.........vars
# ............0
#
# ............0
# .........vars
# ............1............1
# ............0
# ......dense_1
# ............1.........vars
#
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ......dense_2...layersKeras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
#
# File Name                                             Modified             Size
#
# .........vars
# ......dense
# .........vars
# ............0
# ............1
# metadata.json                                  2024-01-18 21:35:30           64
# ......dense_1config.json                                    2024-01-18 21:35:30         2591
# variables.h5                                   2024-01-18 21:35:30        19128
# ............0Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:35:30           64
# config.json                                    2024-01-18 21:35:30         2591
# variables.h5                                   2024-01-18 21:35:30        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
#
#
# ............1metadata.json                                  2024-01-18 21:35:30           64
# config.json                                    2024-01-18 21:35:30         2591
# variables.h5                                   2024-01-18 21:35:30        19128
# ...layersKeras model archive loading:
#
# File Name                                             Modified             Size
#
# ......dense_2
# .........vars............0
#
# .........vars............0
#
# ............1
#
# ......dense......dense_1............1............0
# ......dense_3
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# metadata.json                                  2024-01-18 21:35:30           64
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:35:30           64
# config.json                                    2024-01-18 21:35:30         2591
# variables.h5                                   2024-01-18 21:35:30        19128
# config.json                                    2024-01-18 21:35:30         2591
# Keras model archive loading:
# variables.h5                                   2024-01-18 21:35:30        19128
# ......dense_3
# .........varsKeras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
#
# metadata.json                                  2024-01-18 21:35:30           64
# config.json                                    2024-01-18 21:35:30         2591
# variables.h5                                   2024-01-18 21:35:30        19128
# ............0Keras model archive loading:
# .........varsFile Name                                             Modified             Size
# File Name                                             Modified             Size
#
# metadata.json                                  2024-01-18 21:35:30           64
# ............0metadata.json                                  2024-01-18 21:35:30           64
#
# config.json                                    2024-01-18 21:35:30         2591
#
# variables.h5                                   2024-01-18 21:35:30        19128
#
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# ............1File Name                                             Modified             Size
#
# metadata.json                                  2024-01-18 21:35:30           64
# config.json                                    2024-01-18 21:35:30         2591
# variables.h5                                   2024-01-18 21:35:30        19128
# ......dense_1............1Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:Keras model archive loading:
#
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# File Name                                             Modified             Size
#
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# ............1File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:35:30           64
# config.json                                    2024-01-18 21:35:30         2591
# variables.h5                                   2024-01-18 21:35:30        19128
# ......dense_2
# config.json                                    2024-01-18 21:35:30         2591
# variables.h5                                   2024-01-18 21:35:30        19128
#
#
# Keras model archive loading:
# .........varsmetadata.json                                  2024-01-18 21:35:30           64
#
#
# config.json                                    2024-01-18 21:35:30         2591
#
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# ......input_layer.........varsFile Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:35:30           64
# config.json                                    2024-01-18 21:35:30         2591
# variables.h5                                   2024-01-18 21:35:30        19128
# File Name                                             Modified             Size
# .........varsKeras model archive loading:
#
# ............0
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:35:30           64
# ............0config.json                                    2024-01-18 21:35:30         2591
# variables.h5                                   2024-01-18 21:35:30        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:metadata.json                                  2024-01-18 21:35:30           64
# variables.h5                                   2024-01-18 21:35:30        19128
#
#
# .........vars............1
#
#
# ............1............0............0
#
# ...layers......input_layer
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
#
# ............1Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:35:30           64
# config.json                                    2024-01-18 21:35:30         2591
# ......dense_2variables.h5                                   2024-01-18 21:35:30        19128
# .........vars
#
# ...varsKeras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
#
# ......dense_2Keras model archive loading:
#
# File Name                                             Modified             Size
# .........vars......dense
#
# config.json                                    2024-01-18 21:35:30         2591
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# .........varsvariables.h5                                   2024-01-18 21:35:30        19128
#
# .........varsKeras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ............0
# .........vars
# ...layers...layers
#
# metadata.json                                  2024-01-18 21:35:30           64
# ...vars
#
# config.json                                    2024-01-18 21:35:30         2591
#
# ............0
# ............1............1......dense
#
#
# .........vars............1......dense_3
#
#
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:............0.........vars
# ......dense......dense_1variables.h5                                   2024-01-18 21:35:30        19128
#
#
#
#
# ...layers
# ...layers............1
# ............0
# ............0
#
#
#
# .........vars......dense_1............1
#
#
# .........vars............0......dense_3
#
# ............0......dense
#
# .........vars
# .........vars
# ............0
#
# ............1
# ......dense_3
# ......dense.........vars
#
# ............1Keras model archive saving:
# File Name                                             Modified             Size
# .........varsmetadata.json                                  2024-01-18 21:35:30           64
# config.json                                    2024-01-18 21:35:30         2591
#
# variables.h5                                   2024-01-18 21:35:30        19128
# ............0
# .........vars
# ............0
# Keras model archive loading:
# ............1Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ............1......input_layer
#
# .........vars............0
#
# ......dense_1
# ......dense_2
#
# ......dense
#
# ............0............1.........vars......dense_2...layersmetadata.json                                  2024-01-18 21:35:30           64
#
# ...vars
#
# File Name                                             Modified             Size
# .........vars
#
# .........vars
# ............0
# ............0config.json                                    2024-01-18 21:35:30         2591
# ............1......input_layer
#
# variables.h5                                   2024-01-18 21:35:30        19128
# ............1
#
# ............1......dense_1Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
#
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ............1......dense_3
#
#
#
# .........vars...layers............0......dense_1Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
#
# metadata.json                                  2024-01-18 21:35:30           64
# config.json                                    2024-01-18 21:35:30         2591
# variables.h5                                   2024-01-18 21:35:30        19128
# .........vars
# .........vars............0
# ......input_layer.........vars
#
# .........vars............1
#
# Keras model archive loading:
# ............0
#
# ............1
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:35:30           64
#
# config.json                                    2024-01-18 21:35:30         2591
#
#
# variables.h5                                   2024-01-18 21:35:30        19128
# ......dense_1...layers
# ............0
# ......dense............1............1............0
#
# .........vars
#
# ......dense_2......dense_2
# .........vars
# ............1
#
# .........vars
# .........vars
# ............0
# ............1
#
# ...vars......dense_3......dense_3
#
# .........vars
# ............0.........vars
#
# ......input_layer...vars
#
# .........vars............0
# ......dense
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
#
# ......dense_2
# ............1
# .........vars............0
#
# ......dense_2
# ............0.........vars
#
#
# ............0...vars
#
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:............1............0
#
# .........vars.........vars............1............1
#
# ............0
# ......dense_3
#
#
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
#
# ............1......dense_2
# .........vars
# ............0
#
# ......input_layer......dense_3
#
# .........varsKeras weights file (<HDF5 file "variables.h5" (mode r)>) loading:.........vars
# ............1
# ............1
# ...vars
#
#
#
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
#
# metadata.json                                  2024-01-18 21:35:30           64
# config.json                                    2024-01-18 21:35:30         2591
# variables.h5                                   2024-01-18 21:35:30        19128
# ......dense_2
# ............0
# ...layers......dense_3Keras model archive loading:
# ............1
#
# ............0......input_layer.........vars.........varsFile Name                                             Modified             Size
#
#
# metadata.json                                  2024-01-18 21:35:30           64
#
#
# ............0............0......dense.........vars
# ............1
#
# config.json                                    2024-01-18 21:35:30         2591
# ......input_layervariables.h5                                   2024-01-18 21:35:30        19128
# .........vars
#
# .........vars...varsKeras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:35:30           64
# config.json                                    2024-01-18 21:35:30         2591
# variables.h5                                   2024-01-18 21:35:30        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
#
#
# ............0...layers
#
# ......dense_1............0
# Keras model archive loading:
# ............1File Name                                             Modified             Size
#
# ......dense_1
# ......dense
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# .........varsmetadata.json                                  2024-01-18 21:35:30           64
# config.json                                    2024-01-18 21:35:30         2591
# variables.h5                                   2024-01-18 21:35:30        19128
#
# ............1
# metadata.json                                  2024-01-18 21:35:30           64
#
#
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:............0
# ...layersconfig.json                                    2024-01-18 21:35:30         2591
#
# variables.h5                                   2024-01-18 21:35:30        19128
# ......dense_3Keras model archive loading:
# .........varsKeras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
#
# File Name                                             Modified             Size
# .........varsmetadata.json                                  2024-01-18 21:35:30           64
# metadata.json                                  2024-01-18 21:35:30           64
# config.json                                    2024-01-18 21:35:30         2591
# variables.h5                                   2024-01-18 21:35:30        19128
#
#
# Keras model archive loading:
#
# .........vars
# ............0............1
# ............1.........vars
#
# ............0
#
# config.json                                    2024-01-18 21:35:30         2591
# ............1
# File Name                                             Modified             Size
# ......input_layer
# .........vars
# ...varsKeras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ......densevariables.h5                                   2024-01-18 21:35:30        19128
#
# ............1...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
#
# metadata.json                                  2024-01-18 21:35:30           64
# config.json                                    2024-01-18 21:35:30         2591
# variables.h5                                   2024-01-18 21:35:30        19128
#
# metadata.json                                  2024-01-18 21:35:30           64
#
#
#
# ............1............0
# ...varsconfig.json                                    2024-01-18 21:35:30         2591
# ......dense_1Keras model archive loading:
# .........vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:35:30           64
# config.json                                    2024-01-18 21:35:30         2591
# variables.h5                                   2024-01-18 21:35:30        19128
#
# ......dense_2File Name                                             Modified             Size
# ............0
# variables.h5                                   2024-01-18 21:35:30        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:......input_layer
# .........vars
# .........vars......input_layer
# metadata.json                                  2024-01-18 21:35:30           64
#
# ...layers
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 21:35:30           64
# config.json                                    2024-01-18 21:35:30         2591
# config.json                                    2024-01-18 21:35:30         2591
# variables.h5                                   2024-01-18 21:35:30        19128
# Keras model archive loading:
#
# .........vars......dense
#
# ............1
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ............0File Name                                             Modified             Size
#
# variables.h5                                   2024-01-18 21:35:30        19128
# ............1......dense_2............0
# .........vars.........vars
# ...layers...vars
# metadata.json                                  2024-01-18 21:35:30           64
#
#
# .........vars......dense_1
# ...vars
#
#
# config.json                                    2024-01-18 21:35:30         2591
#
# ............1
# ......dense
# variables.h5                                   2024-01-18 21:35:30        19128
#
#
#
# ............1............0......dense_2.........vars.........vars
#
#
# ............1
# ......dense_3
# .........vars............0
# ............0
#
# .........vars
#
# ............0
# ............1......dense_1............0Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
#
# ............1Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:............0
# ...layers
#
#
# ......input_layer
# ......dense_2
#
# .........vars...layers
# ............0
# ............1
#
#
#
# .........vars............1.........vars
# ......dense
# ......dense_3
#
# .........vars
# .........vars...vars............0
#
# ......dense............0
#
# .........vars............1
#
# ............1
# ......dense_3............0
#
# ......dense_3
#
#
# .........vars.........vars......input_layerKeras weights file (<HDF5 file "variables.h5" (mode r)>) loading:............0
#
# ............1............1
# ............1.........vars
# ............0
# ............0
# ......dense_1
# ............1
#
#
#
#
# ............1
# ...vars...layers......dense_1............1
#
#
# ......input_layer.........vars
# .........vars......dense_2
#
#
# .........vars
# ......dense_1...vars......input_layer
#
# .........vars............0............0
# .........vars
#
# ......dense
#
#
#
# ............0............1
# ............1
#
# ......dense_2.........vars.........vars
# ............1
#
# .........vars............0...vars......dense_2
#
#
# ............1
#
#
# ......dense_3
# ......dense_2
# ............0
# ............0.........vars
# .........vars
# ............1
#
#
# ............0............1............0
#
# ............1
# .........vars......dense_3......dense_3
# .........vars
# ............0
# ............1
# .........vars......dense_1
#
#
#
# ............0
#
# ............1
# ............0......dense_3......input_layer
# ............1............1
# .........vars
# .........vars
#
#
# ......input_layer......input_layer
# .........vars
# ...vars
# .........vars
#
# ............0.........vars
#
# ............1...vars
# ...vars
#
# ......dense_2
#
# ............0.........vars
# ............1
#
# ............0......input_layer
#
# .........vars............1
#
# ...vars......dense_3
#
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 23:36:31           64
# config.json                                    2024-01-18 23:36:31         2591
# variables.h5                                   2024-01-18 23:36:31        19128
# metadata.json                                  2024-01-18 21:35:30           64
# config.json                                    2024-01-18 21:35:30         2591
# variables.h5                                   2024-01-18 21:35:30        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 23:36:30           64
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# config.json                                    2024-01-18 23:36:30         2591
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 23:42:58           64
# config.json                                    2024-01-18 23:42:58         2591
# variables.h5                                   2024-01-18 23:42:59        19128
# variables.h5                                   2024-01-18 23:36:30        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 23:43:34           64
# config.json                                    2024-01-18 23:43:34         2591
# variables.h5                                   2024-01-18 23:43:34        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 23:42:58           64
# config.json                                    2024-01-18 23:42:58         2591
# variables.h5                                   2024-01-18 23:42:58        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 23:43:41           64
# config.json                                    2024-01-18 23:43:41         2591
# variables.h5                                   2024-01-18 23:43:41        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 23:43:34           64
# config.json                                    2024-01-18 23:43:34         2591
# variables.h5                                   2024-01-18 23:43:34        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 23:43:40           64
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2024-01-18 23:43:40         2591
# metadata.json                                  2024-01-18 23:44:02           64
# config.json                                    2024-01-18 23:44:02         2591
# variables.h5                                   2024-01-18 23:44:02        19128
# variables.h5                                   2024-01-18 23:43:40        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 23:44:07           64
# config.json                                    2024-01-18 23:44:07         2591
# Keras model archive loading:
# variables.h5                                   2024-01-18 23:44:07        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 23:44:02           64
# config.json                                    2024-01-18 23:44:02         2591
# variables.h5                                   2024-01-18 23:44:02        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 23:44:09           64
# config.json                                    2024-01-18 23:44:09         2591
# variables.h5                                   2024-01-18 23:44:09        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 23:44:06           64
# config.json                                    2024-01-18 23:44:06         2591
# variables.h5                                   2024-01-18 23:44:06        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# Keras model archive loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 23:44:09           64
# config.json                                    2024-01-18 23:44:09         2591
# variables.h5                                   2024-01-18 23:44:09        19128
# File Name                                             Modified             Size
# .........varsmetadata.json                                  2024-01-18 23:44:08           64
#
# ............0config.json                                    2024-01-18 23:44:08         2591
#
# variables.h5                                   2024-01-18 23:44:08        19128
# ............1
# ......dense_1Keras model archive loading:
#
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 23:44:09           64
# config.json                                    2024-01-18 23:44:09         2591
# variables.h5                                   2024-01-18 23:44:09        19128
# metadata.json                                  2024-01-18 23:44:08           64
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:.........vars
#
# ...layers
# ............0config.json                                    2024-01-18 23:44:08         2591
#
# ......dense............1
# variables.h5                                   2024-01-18 23:44:08        19128
# .........vars
# ......dense_2
# ............0
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
#
# ...layers.........vars............1
#
#
# ......dense_1............0......dense
#
# .........vars
# ............1
# ............0
#
# ......dense_3............1
#
# ......dense_1.........vars
# .........vars
# ............0.........vars
# ............0
#
# ............1............1
# ............0
#
#
# ......dense_2............1......dense_2
#
# .........vars
# ......input_layer
#
# .........vars............0
# .........vars............0
#
# ............1
# ......dense_3
# .........vars
# ............1
# ...vars
# ............0
# ......dense_3
# ............1
#
# ......input_layer
# .........vars.........vars
# ...vars
# ............0
# ............1
# ......input_layer
# .........vars
#
# ...vars
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 23:44:08           64
# config.json                                    2024-01-18 23:44:08         2591
# variables.h5                                   2024-01-18 23:44:08        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ...
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 23:44:21           64
# config.json                                    2024-01-18 23:44:21         2591
# Keras model archive loading:
# variables.h5                                   2024-01-18 23:44:21        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 23:44:20           64
# config.json                                    2024-01-18 23:44:20         2591
# variables.h5                                   2024-01-18 23:44:20        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 23:44:23           64
# config.json                                    2024-01-18 23:44:23         2591
# variables.h5                                   2024-01-18 23:44:23        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 23:44:20           64
# config.json                                    2024-01-18 23:44:20         2591
# variables.h5                                   2024-01-18 23:44:20        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 23:44:24           64
# config.json                                    2024-01-18 23:44:24         2591
# variables.h5                                   2024-01-18 23:44:24        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 23:44:22           64
# config.json                                    2024-01-18 23:44:22         2591
# variables.h5                                   2024-01-18 23:44:22        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 23:44:30           64
# config.json                                    2024-01-18 23:44:30         2591
# variables.h5                                   2024-01-18 23:44:30        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 23:44:24           64
# config.json                                    2024-01-18 23:44:24         2591
# variables.h5                                   2024-01-18 23:44:24        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# File Name                                             Modified             Size
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 23:44:33           64
# config.json                                    2024-01-18 23:44:33         2591
# variables.h5                                   2024-01-18 23:44:33        19128
# metadata.json                                  2024-01-18 23:44:30           64
# config.json                                    2024-01-18 23:44:30         2591
# variables.h5                                   2024-01-18 23:44:30        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# File Name                                             Modified             Size
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 23:44:50           64
# config.json                                    2024-01-18 23:44:50         2591
# variables.h5                                   2024-01-18 23:44:50        19128
# metadata.json                                  2024-01-18 23:44:32           64
# config.json                                    2024-01-18 23:44:32         2591
# variables.h5                                   2024-01-18 23:44:32        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 23:45:35           64
# config.json                                    2024-01-18 23:45:35         2591
# variables.h5                                   2024-01-18 23:45:35        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 23:44:50           64
# config.json                                    2024-01-18 23:44:50         2591
# variables.h5                                   2024-01-18 23:44:50        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 23:45:42           64
# config.json                                    2024-01-18 23:45:42         2591
# metadata.json                                  2024-01-18 23:45:34           64
# variables.h5                                   2024-01-18 23:45:42        19128
# config.json                                    2024-01-18 23:45:34         2591
# variables.h5                                   2024-01-18 23:45:34        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# File Name                                             Modified             Size
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 23:45:49           64
# config.json                                    2024-01-18 23:45:49         2591
# variables.h5                                   2024-01-18 23:45:49        19128
# metadata.json                                  2024-01-18 23:45:42           64
# config.json                                    2024-01-18 23:45:42         2591
# variables.h5                                   2024-01-18 23:45:42        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# Keras model archive loading:
# metadata.json                                  2024-01-18 23:46:01           64
# config.json                                    2024-01-18 23:46:01         2591
# File Name                                             Modified             Size
# variables.h5                                   2024-01-18 23:46:01        19128
# metadata.json                                  2024-01-18 23:45:48           64
# config.json                                    2024-01-18 23:45:48         2591
# variables.h5                                   2024-01-18 23:45:48        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 23:46:09           64
# config.json                                    2024-01-18 23:46:09         2591
# variables.h5                                   2024-01-18 23:46:09        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 23:46:00           64
# config.json                                    2024-01-18 23:46:00         2591
# variables.h5                                   2024-01-18 23:46:00        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-01-18 23:46:08           64
# config.json                                    2024-01-18 23:46:08         2591
# variables.h5                                   2024-01-18 23:46:08        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# CPU times: user 1.65 s, sys: 1.59 s, total: 3.23 s
# Wall time: 3h 20min 20s

# %%
nonlinear_rewards_filename = "checkpoints/nonlinear_rewards.pkl"
with open(nonlinear_rewards_filename, 'wb') as file:
    pickle.dump(nonlinear_rewards_dict, file, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open(nonlinear_rewards_filename, "rb") as file:
    nonlinear_rewards_dict = pickle.load(file)

# %%
plot_rewards_dict(nonlinear_rewards_dict, "nonlinear")

# %% [markdown]
# # Cumulative Regret for All Three Settings

# %% [markdown]
# ## Calculations

# %%
# Calculate incremental regret
incremental_homogeneous_regret_dict = {
    method_name: get_avg_stage_reward(homogeneous_rewards_dict["Oracle"]) - get_avg_stage_reward(homogeneous_rewards_dict[method_name])
    for method_name in non_oracle_method_names}
incremental_heterogeneous_regret_dict = {
    method_name: get_avg_stage_reward(heterogeneous_rewards_dict["Oracle"]) - get_avg_stage_reward(heterogeneous_rewards_dict[method_name])
    for method_name in non_oracle_method_names}
incremental_nonlinear_regret_dict = {
    method_name: get_avg_stage_reward(nonlinear_rewards_dict["Oracle"]) - get_avg_stage_reward(nonlinear_rewards_dict[method_name])
    for method_name in non_oracle_method_names}

# Calculate cumulative regret
cumulative_homogeneous_regret_dict = {method_name: np.cumsum(incremental_homogeneous_regret_dict[method_name], axis=0) for method_name in non_oracle_method_names}
cumulative_heterogeneous_regret_dict = {method_name: np.cumsum(incremental_heterogeneous_regret_dict[method_name], axis=0) for method_name in non_oracle_method_names}
cumulative_nonlinear_regret_dict = {method_name: np.cumsum(incremental_nonlinear_regret_dict[method_name], axis=0) for method_name in non_oracle_method_names}

# Final regret
final_homogeneous_regret_df = pd.DataFrame({
    method_name: cumulative_homogeneous_regret_dict[method_name][-1]
    for method_name in non_oracle_method_names})
final_homogeneous_regret_df.to_csv("./checkpoints/final_homogeneous_regret.csv", index=False)

final_heterogeneous_regret_df = pd.DataFrame({
    method_name: cumulative_heterogeneous_regret_dict[method_name][-1]
    for method_name in non_oracle_method_names})
final_heterogeneous_regret_df.to_csv("./checkpoints/final_heterogeneous_regret.csv", index=False)

final_nonlinear_regret_df = pd.DataFrame({
    method_name: cumulative_nonlinear_regret_dict[method_name][-1]
    for method_name in non_oracle_method_names})
final_nonlinear_regret_df.to_csv("./checkpoints/final_nonlinear_regret.csv", index=False)

# %% [markdown]
# ## Plots

# %%
def plot_cumulative_regret(cumulative_regret_dict, setting_name, include_legend=False, loc="main", include_bands=True):
    fig, ax = plt.subplots(1, 1, figsize=(4,4))
    for i, method_name in enumerate(cumulative_regret_dict.keys()):
        color_i = f"C{i}"
        method_means = cumulative_regret_dict[method_name].mean(axis=1)
        method_range = np.arange(method_means.size)
        method_sds = cumulative_regret_dict[method_name].std(axis=1)
        method_lower = method_means - 1.96 * method_sds
        method_upper = method_means + 1.96 * method_sds
        if include_bands:
            ax.fill_between(method_range, method_lower, method_upper, color=color_i, alpha=0.1)
        ax.plot(method_range, method_means, label=method_name, color=color_i)
        
    ax.grid(which='major', color='#DDDDDD', linewidth=0.3)
    ax.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=0.3)
    ax.minorticks_on()
    ax.set_title(setting_name, pad=14, fontsize=16)
    ax.set_ylabel("Cumulative Regret", fontsize=14)
    ax.set_xlabel("Stage", fontsize=14)
    ax.tick_params(axis='both', labelsize=11)
    if include_legend:
        ax.legend(fontsize=11)

    plt.tight_layout()
    plt.subplots_adjust(top=0.85)
    setting_name_for_file = setting_name.replace("(", "").replace(")", "").replace(" ", "-")
    fig.savefig(f"figures/cumulative-regret-{setting_name_for_file}-{loc}.png")
    # fig.suptitle("Comparison of Cumulative Regret by Method")
    plt.show()

main_paper_methods = ["DML-TS-NNR", "IntelPooling", "Neural-Linear", "AC", "Standard"]

plot_cumulative_regret(
    {m:cumulative_homogeneous_regret_dict[m] for m in main_paper_methods},
    setting_name="(a) Homogeneous Users", include_legend=True)

plot_cumulative_regret(
    {m:cumulative_heterogeneous_regret_dict[m] for m in main_paper_methods},
    setting_name="(b) Heterogeneous Users", include_legend=False)

plot_cumulative_regret(
    {m:cumulative_nonlinear_regret_dict[m] for m in main_paper_methods},
    setting_name="(c) Nonlinear Setting", include_legend=False)

# %%
appendix_methods = ["DML-TS-NNR", "DML-TS-NNR-BLM", "DML-TS-SU", "NNR-Linear"]

plot_cumulative_regret(
    {m:cumulative_homogeneous_regret_dict[m] for m in appendix_methods},
    setting_name="(a) Homogeneous Users", include_legend=True, loc="app")

plot_cumulative_regret(
    {m:cumulative_heterogeneous_regret_dict[m] for m in appendix_methods},
    setting_name="(b) Heterogeneous Users", include_legend=False, loc="app")

plot_cumulative_regret(
    {m:cumulative_nonlinear_regret_dict[m] for m in appendix_methods},
    setting_name="(c) Nonlinear Setting", include_legend=False, loc="app")

# %% [markdown]
# ## Comparison Tables

# %% [markdown]
# ### Extra

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
final_homogeneous_regret_df = pd.read_csv("./checkpoints/final_homogeneous_regret.csv")
final_heterogeneous_regret_df = pd.read_csv("./checkpoints/final_heterogeneous_regret.csv")
final_nonlinear_regret_df = pd.read_csv("./checkpoints/final_nonlinear_regret.csv")

# %%
non_oracle_method_names_sorted = [
    'DML-TS-NNR',
    'DML-TS-NNR-BLM',
    'DML-TS-SU',
    'NNR-Linear',
    'IntelPooling',
    'Neural-Linear',
    'Standard',
    'AC',
]

# %%
def create_comparison_df(final_regret_df):
    comparison_outer_list = []
    win_percentages = []
    for method_row in non_oracle_method_names_sorted:
        comparison_inner_list = []
        win_percentage = 0.
        for method_column in non_oracle_method_names_sorted:
            diffs = final_regret_df[method_column] - final_regret_df[method_row]
            percent_row_better = np.mean(diffs > 0)
            avg_diff = np.mean(diffs)
            p_value = ttest_1samp(diffs, popmean=0).pvalue
            if method_row == method_column:
                cell_text = "-"
            else:
                win_percentage += percent_row_better / (len(non_oracle_method_names_sorted) - 1)
                cell_text = f"{percent_row_better:.0%}{'*' if p_value < 0.05 else ''}"
            comparison_inner_list.append(cell_text)
        comparison_outer_list.append(comparison_inner_list)
        win_percentages.append(f"{win_percentage:.0%}")
    comparison_df = pd.DataFrame(
        comparison_outer_list,
        index=[f"{i+1}. {n}" for i, n in enumerate(non_oracle_method_names_sorted)],
        columns=range(1, len(non_oracle_method_names_sorted)+1))
    comparison_df["\textbf{Avg}"] = win_percentages
    latex_table = comparison_df.to_latex(escape=False).replace("%", "\%")
    print(latex_table)
    return comparison_df

# %%
homogeneous_comparison_df = create_comparison_df(final_homogeneous_regret_df)
homogeneous_comparison_df
# Out:
# \begin{tabular}{llllllllll}
# \toprule
#  & 1 & 2 & 3 & 4 & 5 & 6 & 7 & 8 & 	extbf{Avg} \\
# \midrule
# 1. DML-TS-NNR & - & 58\%* & 48\% & 52\% & 32\%* & 100\%* & 100\%* & 100\%* & 70\% \\
# 2. DML-TS-NNR-BLM & 42\%* & - & 40\%* & 36\%* & 22\%* & 100\%* & 100\%* & 100\%* & 63\% \\
# 3. DML-TS-SU & 52\% & 60\%* & - & 48\% & 34\%* & 100\%* & 100\%* & 100\%* & 71\% \\
# 4. NNR-Linear & 48\% & 64\%* & 52\% & - & 32\%* & 100\%* & 100\%* & 100\%* & 71\% \\
# 5. IntelPooling & 68\%* & 78\%* & 66\%* & 68\%* & - & 100\%* & 100\%* & 100\%* & 83\% \\
# 6. Neural-Linear & 0\%* & 0\%* & 0\%* & 0\%* & 0\%* & - & 100\%* & 100\%* & 29\% \\
# 7. Standard & 0\%* & 0\%* & 0\%* & 0\%* & 0\%* & 0\%* & - & 100\%* & 14\% \\
# 8. AC & 0\%* & 0\%* & 0\%* & 0\%* & 0\%* & 0\%* & 0\%* & - & 0\% \\
# \bottomrule
# \end{tabular}
#                       1     2     3     4     5      6      7      8  \
# 1. DML-TS-NNR         -  58%*   48%   52%  32%*  100%*  100%*  100%*
# 2. DML-TS-NNR-BLM  42%*     -  40%*  36%*  22%*  100%*  100%*  100%*
# 3. DML-TS-SU        52%  60%*     -   48%  34%*  100%*  100%*  100%*
# 4. NNR-Linear       48%  64%*   52%     -  32%*  100%*  100%*  100%*
# 5. IntelPooling    68%*  78%*  66%*  68%*     -  100%*  100%*  100%*
# 6. Neural-Linear    0%*   0%*   0%*   0%*   0%*      -  100%*  100%*
# 7. Standard         0%*   0%*   0%*   0%*   0%*    0%*      -  100%*
# 8. AC               0%*   0%*   0%*   0%*   0%*    0%*    0%*      -
#
#                   \textbf{Avg}
# 1. DML-TS-NNR              70%
# 2. DML-TS-NNR-BLM          63%
# 3. DML-TS-SU               71%
# 4. NNR-Linear              71%
# 5. IntelPooling            83%
# 6. Neural-Linear           29%
# 7. Standard                14%
# 8. AC                       0%

# %%
heterogeneous_comparison_df = create_comparison_df(final_heterogeneous_regret_df)
heterogeneous_comparison_df
# Out:
# \begin{tabular}{llllllllll}
# \toprule
#  & 1 & 2 & 3 & 4 & 5 & 6 & 7 & 8 & 	extbf{Avg} \\
# \midrule
# 1. DML-TS-NNR & - & 50\% & 78\%* & 54\% & 100\%* & 100\%* & 100\%* & 100\%* & 83\% \\
# 2. DML-TS-NNR-BLM & 50\% & - & 70\%* & 50\% & 100\%* & 100\%* & 100\%* & 100\%* & 81\% \\
# 3. DML-TS-SU & 22\%* & 30\%* & - & 20\%* & 92\%* & 100\%* & 100\%* & 100\%* & 66\% \\
# 4. NNR-Linear & 46\% & 50\% & 80\%* & - & 100\%* & 100\%* & 100\%* & 100\%* & 82\% \\
# 5. IntelPooling & 0\%* & 0\%* & 8\%* & 0\%* & - & 98\%* & 100\%* & 100\%* & 44\% \\
# 6. Neural-Linear & 0\%* & 0\%* & 0\%* & 0\%* & 2\%* & - & 96\%* & 100\%* & 28\% \\
# 7. Standard & 0\%* & 0\%* & 0\%* & 0\%* & 0\%* & 4\%* & - & 100\%* & 15\% \\
# 8. AC & 0\%* & 0\%* & 0\%* & 0\%* & 0\%* & 0\%* & 0\%* & - & 0\% \\
# \bottomrule
# \end{tabular}
#                       1     2     3     4      5      6      7      8  \
# 1. DML-TS-NNR         -   50%  78%*   54%  100%*  100%*  100%*  100%*
# 2. DML-TS-NNR-BLM   50%     -  70%*   50%  100%*  100%*  100%*  100%*
# 3. DML-TS-SU       22%*  30%*     -  20%*   92%*  100%*  100%*  100%*
# 4. NNR-Linear       46%   50%  80%*     -  100%*  100%*  100%*  100%*
# 5. IntelPooling     0%*   0%*   8%*   0%*      -   98%*  100%*  100%*
# 6. Neural-Linear    0%*   0%*   0%*   0%*    2%*      -   96%*  100%*
# 7. Standard         0%*   0%*   0%*   0%*    0%*    4%*      -  100%*
# 8. AC               0%*   0%*   0%*   0%*    0%*    0%*    0%*      -
#
#                   \textbf{Avg}
# 1. DML-TS-NNR              83%
# 2. DML-TS-NNR-BLM          81%
# 3. DML-TS-SU               66%
# 4. NNR-Linear              82%
# 5. IntelPooling            44%
# 6. Neural-Linear           28%
# 7. Standard                15%
# 8. AC                       0%

# %% [markdown]
# ### Nonlinear Setting

# %%
nonlinear_comparison_df = create_comparison_df(final_nonlinear_regret_df)
nonlinear_comparison_df
# Out:
# \begin{tabular}{llllllllll}
# \toprule
#  & 1 & 2 & 3 & 4 & 5 & 6 & 7 & 8 & 	extbf{Avg} \\
# \midrule
# 1. DML-TS-NNR & - & 54\% & 100\%* & 98\%* & 98\%* & 100\%* & 100\%* & 100\%* & 93\% \\
# 2. DML-TS-NNR-BLM & 46\% & - & 94\%* & 98\%* & 100\%* & 100\%* & 100\%* & 100\%* & 91\% \\
# 3. DML-TS-SU & 0\%* & 6\%* & - & 42\% & 78\%* & 100\%* & 100\%* & 100\%* & 61\% \\
# 4. NNR-Linear & 2\%* & 2\%* & 58\% & - & 82\%* & 100\%* & 100\%* & 100\%* & 63\% \\
# 5. IntelPooling & 2\%* & 0\%* & 22\%* & 18\%* & - & 98\%* & 100\%* & 100\%* & 49\% \\
# 6. Neural-Linear & 0\%* & 0\%* & 0\%* & 0\%* & 2\%* & - & 98\%* & 100\%* & 29\% \\
# 7. Standard & 0\%* & 0\%* & 0\%* & 0\%* & 0\%* & 2\%* & - & 100\%* & 15\% \\
# 8. AC & 0\%* & 0\%* & 0\%* & 0\%* & 0\%* & 0\%* & 0\%* & - & 0\% \\
# \bottomrule
# \end{tabular}
#                      1    2      3     4      5      6      7      8  \
# 1. DML-TS-NNR        -  54%  100%*  98%*   98%*  100%*  100%*  100%*
# 2. DML-TS-NNR-BLM  46%    -   94%*  98%*  100%*  100%*  100%*  100%*
# 3. DML-TS-SU       0%*  6%*      -   42%   78%*  100%*  100%*  100%*
# 4. NNR-Linear      2%*  2%*    58%     -   82%*  100%*  100%*  100%*
# 5. IntelPooling    2%*  0%*   22%*  18%*      -   98%*  100%*  100%*
# 6. Neural-Linear   0%*  0%*    0%*   0%*    2%*      -   98%*  100%*
# 7. Standard        0%*  0%*    0%*   0%*    0%*    2%*      -  100%*
# 8. AC              0%*  0%*    0%*   0%*    0%*    0%*    0%*      -
#
#                   \textbf{Avg}
# 1. DML-TS-NNR              93%
# 2. DML-TS-NNR-BLM          91%
# 3. DML-TS-SU               61%
# 4. NNR-Linear              63%
# 5. IntelPooling            49%
# 6. Neural-Linear           29%
# 7. Standard                15%
# 8. AC                       0%

# %%
final_nonlinear_regret_df
# Out:
#     IntelPooling  DML-TS-NNR-BLM  DML-TS-NNR  DML-TS-SU          AC  \
# 0      55.576990       33.966981   30.054828  48.799018  138.513413
# 1      48.923903       29.981434   25.244598  51.860360  140.556270
# 2      56.722796       34.865681   31.971853  55.636581  141.801915
# 3      46.745882       28.946492   40.598736  49.958015  149.383349
# 4      50.538686       36.650555   39.418395  44.087625  142.731606
# 5      61.729105       30.866509   40.226560  49.285093  145.028294
# 6      50.860804       34.887454   45.191489  47.714551  139.644067
# 7      50.807392       44.709913   42.889980  44.320664  139.019617
# 8      56.341955       31.746776   38.548377  41.532534  136.521394
# 9      61.939008       43.425106   27.783264  53.003237  140.829186
# 10     61.517221       38.212268   41.750038  53.720834  142.380755
# 11     58.277170       30.531519   43.112162  52.371128  142.995263
# 12     51.282720       37.614803   38.826121  46.866085  146.052129
# 13     51.874542       31.634071   30.158223  55.279568  133.504922
# 14     51.032911       35.525086   35.584669  42.003620  142.598500
# 15     61.522746       40.800853   41.456987  59.104768  145.384761
# 16     53.562890       38.323289   30.364017  50.781073  143.123987
# 17     56.871841       44.314658   33.361517  52.296738  145.037578
# 18     52.296569       33.648263   30.318445  37.682238  140.533977
# 19     64.004699       33.516380   35.540572  64.758161  137.244472
# 20     54.982109       34.824564   44.795170  57.099450  143.498067
# 21     68.398265       39.155566   35.210874  56.814073  145.742553
# 22     50.323960       32.327796   34.543637  43.365413  141.232783
# 23     43.940783       40.877486   50.271759  57.192275  146.715340
# 24     58.870689       45.411077   54.213978  55.851051  140.404113
# 25     54.475015       32.470345   28.258224  44.647629  140.181856
# 26     54.649352       45.225048   38.482980  51.999919  144.477938
# 27     72.301914       34.446434   39.189401  62.135880  148.005048
# 28     56.119876       35.198928   28.465759  54.105678  144.076621
# 29     61.640178       32.353737   29.588015  54.205220  143.336099
# 30     64.175446       37.181643   36.436455  49.181508  146.901972
# 31     63.534166       34.883481   37.583642  58.360155  139.109338
# 32     58.022521       39.533214   30.953508  60.159756  148.116072
# 33     55.950615       43.329021   35.691727  55.315496  149.548246
# 34     63.710228       33.305381   39.411165  59.092620  146.300877
# 35     56.772253       41.605757   37.125087  56.749705  145.692681
# 36     59.408928       41.395643   33.395996  53.515859  145.695721
# 37     62.954547       37.970062   38.215466  56.167605  145.997464
# 38     58.384693       46.832835   33.789284  61.342332  151.704396
# 39     49.429000       40.071691   36.170534  49.359753  144.337853
# 40     54.535851       34.633198   37.711891  51.170644  137.508303
# 41     61.385240       47.595773   39.096667  56.621880  139.287204
# 42     63.927388       49.454081   35.040120  47.697763  143.116442
# 43     55.551588       32.101481   33.658414  58.716037  141.050021
# 44     56.236183       37.724701   30.486205  50.856571  148.950528
# 45     58.268356       50.293324   28.028266  47.462009  141.507458
# 46     50.215999       44.271072   36.461230  51.981207  137.488988
# 47     50.396227       40.472406   44.468074  61.221354  148.212770
# 48     69.193393       34.460084   42.907217  50.462731  140.082458
# 49     55.409855       36.569439   32.873946  55.151045  138.596693
#
#      Standard  Neural-Linear  NNR-Linear
# 0   84.164855      67.808647   50.465717
# 1   69.450685      71.242800   50.160768
# 2   75.972919      65.884300   46.095840
# 3   86.952215      70.675534   42.921491
# 4   79.730129      62.692693   46.876672
# 5   83.884281      69.931121   46.822268
# 6   86.083170      74.700186   54.588442
# 7   81.792206      63.389144   41.255705
# 8   86.701797      61.517353   42.156404
# 9   87.312895      67.703070   54.800396
# 10  84.220612      69.123475   52.689352
# 11  82.371890      70.600178   49.020456
# 12  82.789863      75.043506   50.190615
# 13  81.067391      65.088300   61.140790
# 14  76.726821      67.368637   51.061568
# 15  87.710628      83.927759   46.610600
# 16  83.375378      71.069081   46.920337
# 17  88.887055      70.330715   51.425418
# 18  84.515192      63.067708   42.668139
# 19  86.005826      70.938565   42.927398
# 20  89.722356      69.657156   50.974878
# 21  82.573444      72.918175   51.470368
# 22  77.674118      69.821811   44.131694
# 23  85.222269      73.632074   51.536431
# 24  85.461643      73.276339   54.589326
# 25  82.879117      67.342751   54.025119
# 26  90.305259      71.411107   67.235460
# 27  90.612130      75.002305   53.645541
# 28  78.366289      67.602582   48.505292
# 29  90.771503      64.445188   57.561877
# 30  83.177053      77.694433   48.201284
# 31  82.671295      68.614657   51.105448
# 32  81.092797      66.711518   57.953888
# 33  83.677102      71.927176   48.101625
# 34  75.479292      64.996068   53.312106
# 35  85.955299      68.978046   52.252077
# 36  93.675292      75.419340   55.833799
# 37  81.300781      78.558149   56.699888
# 38  90.846935      74.009821   65.401487
# 39  83.419900      74.272571   62.423733
# 40  85.100476      72.350216   50.384238
# 41  89.096055      69.694035   54.315942
# 42  85.619451      75.538397   50.626475
# 43  86.003789      63.720070   50.077558
# 44  90.722266      67.903734   54.030784
# 45  86.962342      70.383371   53.568393
# 46  87.841111      78.399327   52.802834
# 47  80.782026      67.127695   49.126246
# 48  81.352122      68.027975   46.754308
# 49  81.064673      69.884190   48.544099

# %%
sns.kdeplot(data=final_homogeneous_regret_df)
plt.show()

sns.kdeplot(data=final_heterogeneous_regret_df)
plt.show()

sns.kdeplot(data=final_nonlinear_regret_df)
plt.show()
